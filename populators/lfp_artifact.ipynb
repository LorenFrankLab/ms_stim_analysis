# %%
"ms_stim_difference",
            {
                "artifact_detection_algorithm": "difference",
                "artifact_detection_algorithm_params": {
                    "amplitude_thresh_1st": 500,  # must be None or >= 0
                    "proportion_above_thresh_1st": 0.1,
                    "amplitude_thresh_2nd": 1000,  # must be None or >= 0
                    "proportion_above_thresh_2nd": 0.05,
                    "removal_window_ms": 10.0,  # in milliseconds
                    "local_window_ms": 40.0,  # in milliseconds
                },
                "referencing":
            },

# %%
# %load_ext autoreload
# %autoreload 2
from spyglass.lfp.v1 import LFPArtifactDetection, LFPArtifactDetectionSelection, LFPArtifactDetectionParameters, LFPV1

LFPArtifactDetection()
LFPArtifactDetectionParameters().fetch("artifact_params")[0]

LFPArtifactDetectionSelection()

key_list = []
for animal in ['Winnie',"Wallie","Yoshi","Totoro","Olive","Dan","Odin","Frodo","Sam","Banner"]:
       for artifact_key in (LFPV1 & f"nwb_file_name LIKE '{animal}%'").fetch("KEY",as_dict = True):
              artifact_key['artifact_params_name'] = 'default_difference'
              LFPArtifactDetectionSelection().insert1(artifact_key,skip_duplicates=True)
              key_list.append(artifact_key)
              # break
       # break
LFPArtifactDetection.populate(key_list,processes=16)
              
              
# key = {"nwb_file_name":"Winnie20220713_.nwb",
#        "target_interval_list_name":"pos 1 valid times"}
# artifact_key = (LFPV1() & key).fetch("KEY",as_dict = True)[0]
# artifact_key['artifact_params_name'] = 'default_difference_ref'
# LFPArtifactDetectionSelection().insert1(artifact_key,skip_duplicates=True)
# LFPArtifactDetectionSelection & artifact_key
# LFPArtifactDetection.populate(artifact_key)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
basic_key = {'nwb_file_name': 'Wallie20220912_.nwb',
 'target_interval_list_name': 'pos 0 valid times'}
basic_key = "nwb_file_name LIKE 'Bilbo%'"#{'nwb_file_name': 'Bilbo20230724_.nwb',
#  'target_interval_list_name': 'pos 0 valid times'
#  }
# {'nwb_file_name': 'Bilbo20230724_.nwb',
#  'target_interval_list_name': 'pos 0 valid times'}

key_list = []
for artifact_key in (LFPV1 & basic_key).fetch("KEY",as_dict = True):
    print(artifact_key)
    artifact_key['artifact_params_name'] = 'default_difference'
    LFPArtifactDetectionSelection().insert1(artifact_key,skip_duplicates=True)
    key_list.append(artifact_key)
LFPArtifactDetection.populate(key_list,processes=16)   
LFPArtifactDetection & key_list
# Out:
# {'nwb_file_name': 'Bilbo20230722_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 0 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230722_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 1 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230722_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 2 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230722_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 3 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230722_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 4 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230724_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 0 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230724_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 1 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230724_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 10 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230724_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 11 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230724_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 12 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230724_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 2 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230724_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 3 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230724_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 4 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230724_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 5 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230724_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 6 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230724_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 7 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230724_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 8 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230724_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 9 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230725_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 0 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230725_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 1 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230725_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 10 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230725_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 11 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230725_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 2 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230725_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 3 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230725_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 4 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230725_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 5 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230725_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 6 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230725_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 7 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230725_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 8 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230725_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 9 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230726_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 0 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230726_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 1 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230726_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 2 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230726_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 3 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230726_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 4 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230726_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 5 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230726_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 6 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 0 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 1 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 10 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 11 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 12 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 13 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 14 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 15 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 16 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 2 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 3 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 4 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 5 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 6 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 7 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 8 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230802_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 9 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230804_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 0 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230804_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 1 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230804_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 2 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230804_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 3 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# {'nwb_file_name': 'Bilbo20230804_.nwb', 'lfp_electrode_group_name': 'tetrode_sample_Bilbo', 'target_interval_list_name': 'pos 4 valid times', 'filter_name': 'LFP 0-400 Hz', 'filter_sampling_rate': 30000}
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 927, in format
#     return fmt.format(record)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 663, in format
#     record.message = record.getMessage()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 367, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_4026098/2508347105.py", line 15, in <module>
#     LFPArtifactDetection.populate(key_list,processes=16)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 248, in populate
#     with mp.Pool(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 212, in __init__
#     self._repopulate_pool()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 303, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 326, in _repopulate_pool_static
#     w.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/context.py", line 277, in _Popen
#     return Popen(process_obj)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 42, in _call_populate1
#     return process.table._populate1(key, process.jobs, **process.populate_kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 292, in _populate1
#     make(dict(key), **(make_kwargs or {}))
#   File "/home/sambray/Documents/spyglass/src/spyglass/lfp/v1/lfp_artifact.py", line 174, in make
#     ) = ARTIFACT_DETECTION_ALGORITHMS[algorithm](
#   File "/home/sambray/Documents/spyglass/src/spyglass/lfp/v1/lfp_artifact_difference_detection.py", line 105, in difference_artifact_detector
#     logger.info("num tets 1", nelect_above_1st, "num tets 2", nelect_above_2nd)
# Message: 'num tets 1'
# Arguments: (2.0, 'num tets 2', 1.0)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 927, in format
#     return fmt.format(record)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 663, in format
#     record.message = record.getMessage()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 367, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_4026098/2508347105.py", line 15, in <module>
#     LFPArtifactDetection.populate(key_list,processes=16)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 248, in populate
#     with mp.Pool(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 212, in __init__
#     self._repopulate_pool()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 303, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 326, in _repopulate_pool_static
#     w.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/context.py", line 277, in _Popen
#     return Popen(process_obj)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 42, in _call_populate1
#     return process.table._populate1(key, process.jobs, **process.populate_kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 292, in _populate1
#     make(dict(key), **(make_kwargs or {}))
#   File "/home/sambray/Documents/spyglass/src/spyglass/lfp/v1/lfp_artifact.py", line 174, in make
#     ) = ARTIFACT_DETECTION_ALGORITHMS[algorithm](
#   File "/home/sambray/Documents/spyglass/src/spyglass/lfp/v1/lfp_artifact_difference_detection.py", line 106, in difference_artifact_detector
#     logger.info("data shape", recording.shape)
# Message: 'data shape'
# Arguments: ((767450, 14),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 927, in format
#     return fmt.format(record)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 663, in format
#     record.message = record.getMessage()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 367, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_4026098/2508347105.py", line 15, in <module>
#     LFPArtifactDetection.populate(key_list,processes=16)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 248, in populate
#     with mp.Pool(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 212, in __init__
#     self._repopulate_pool()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 303, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 326, in _repopulate_pool_static
#     w.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/context.py", line 277, in _Popen
#     return Popen(process_obj)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 42, in _call_populate1
#     return process.table._populate1(key, process.jobs, **process.populate_kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 292, in _populate1
#     make(dict(key), **(make_kwargs or {}))
#   File "/home/sambray/Documents/spyglass/src/spyglass/lfp/v1/lfp_artifact.py", line 174, in make
#     ) = ARTIFACT_DETECTION_ALGORITHMS[algorithm](
#   File "/home/sambray/Documents/spyglass/src/spyglass/lfp/v1/lfp_artifact_difference_detection.py", line 105, in difference_artifact_detector
#     logger.info("num tets 1", nelect_above_1st, "num tets 2", nelect_above_2nd)
# Message: 'num tets 1'
# Arguments: (2.0, 'num tets 2', 1.0)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 927, in format
#     return fmt.format(record)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 663, in format
#     record.message = record.getMessage()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 367, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_4026098/2508347105.py", line 15, in <module>
#     LFPArtifactDetection.populate(key_list,processes=16)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 248, in populate
#     with mp.Pool(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 212, in __init__
#     self._repopulate_pool()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 303, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 326, in _repopulate_pool_static
#     w.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/context.py", line 277, in _Popen
#     return Popen(process_obj)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 42, in _call_populate1
#     return process.table._populate1(key, process.jobs, **process.populate_kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 292, in _populate1
#     make(dict(key), **(make_kwargs or {}))
#   File "/home/sambray/Documents/spyglass/src/spyglass/lfp/v1/lfp_artifact.py", line 174, in make
#     ) = ARTIFACT_DETECTION_ALGORITHMS[algorithm](
#   File "/home/sambray/Documents/spyglass/src/spyglass/lfp/v1/lfp_artifact_difference_detection.py", line 106, in difference_artifact_detector
#     logger.info("data shape", recording.shape)
# Message: 'data shape'
# Arguments: ((754705, 14),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 927, in format
#     return fmt.format(record)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 663, in format
#     record.message = record.getMessage()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 367, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_4026098/2508347105.py", line 15, in <module>
#     LFPArtifactDetection.populate(key_list,processes=16)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 248, in populate
#     with mp.Pool(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 212, in __init__
#     self._repopulate_pool()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 303, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 326, in _repopulate_pool_static
#     w.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/context.py", line 277, in _Popen
#     return Popen(process_obj)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 42, in _call_populate1
#     return process.table._populate1(key, process.jobs, **process.populate_kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 292, in _populate1
#     make(dict(key), **(make_kwargs or {}))
#   File "/home/sambray/Documents/spyglass/src/spyglass/lfp/v1/lfp_artifact.py", line 174, in make
#     ) = ARTIFACT_DETECTION_ALGORITHMS[algorithm](
#   File "/home/sambray/Documents/spyglass/src/spyglass/lfp/v1/lfp_artifact_difference_detection.py", line 105, in difference_artifact_detector
#     logger.info("num tets 1", nelect_above_1st, "num tets 2", nelect_above_2nd)
# Message: 'num tets 1'
# Arguments: (2.0, 'num tets 2', 1.0)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 927, in format
#     return fmt.format(record)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 663, in format
#     record.message = record.getMessage()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 367, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
# ...
#     ) = ARTIFACT_DETECTION_ALGORITHMS[algorithm](
#   File "/home/sambray/Documents/spyglass/src/spyglass/lfp/v1/lfp_artifact_difference_detection.py", line 170, in difference_artifact_detector
#     logger.info("detected ", artifact_frames.shape[0], " artifacts")
# Message: 'detected '
# Arguments: (8331, ' artifacts')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 927, in format
#     return fmt.format(record)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 663, in format
#     record.message = record.getMessage()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 367, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_4026098/2508347105.py", line 15, in <module>
#     LFPArtifactDetection.populate(key_list,processes=16)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 248, in populate
#     with mp.Pool(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 212, in __init__
#     self._repopulate_pool()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 303, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 326, in _repopulate_pool_static
#     w.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/context.py", line 277, in _Popen
#     return Popen(process_obj)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 42, in _call_populate1
#     return process.table._populate1(key, process.jobs, **process.populate_kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 292, in _populate1
#     make(dict(key), **(make_kwargs or {}))
#   File "/home/sambray/Documents/spyglass/src/spyglass/lfp/v1/lfp_artifact.py", line 174, in make
#     ) = ARTIFACT_DETECTION_ALGORITHMS[algorithm](
#   File "/home/sambray/Documents/spyglass/src/spyglass/lfp/v1/lfp_artifact_difference_detection.py", line 133, in difference_artifact_detector
#     logger.info("thresh", amplitude_thresh_2nd, "window", local_window)
# Message: 'thresh'
# Arguments: (1000, 'window', 20)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 927, in format
#     return fmt.format(record)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 663, in format
#     record.message = record.getMessage()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/logging/__init__.py", line 367, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_4026098/2508347105.py", line 15, in <module>
#     LFPArtifactDetection.populate(key_list,processes=16)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 248, in populate
#     with mp.Pool(
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 212, in __init__
#     self._repopulate_pool()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 303, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 326, in _repopulate_pool_static
#     w.start()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/context.py", line 277, in _Popen
#     return Popen(process_obj)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 42, in _call_populate1
#     return process.table._populate1(key, process.jobs, **process.populate_kwargs)
#   File "/home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/datajoint/autopopulate.py", line 292, in _populate1
#     make(dict(key), **(make_kwargs or {}))
#   File "/home/sambray/Documents/spyglass/src/spyglass/lfp/v1/lfp_artifact.py", line 174, in make
#     ) = ARTIFACT_DETECTION_ALGORITHMS[algorithm](
#   File "/home/sambray/Documents/spyglass/src/spyglass/lfp/v1/lfp_artifact_difference_detection.py", line 170, in difference_artifact_detector
#     logger.info("detected ", artifact_frames.shape[0], " artifacts")
# Message: 'detected '
# Arguments: (135726, ' artifacts')
# *nwb_file_name *lfp_electrode *target_interv *filter_name   *filter_sampli *artifact_para artifact_t artifact_r artifact_remov
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +--------+ +------------+
# Bilbo20230722_ tetrode_sample pos 0 valid ti LFP 0-400 Hz   30000          default_differ =BLOB=     =BLOB=     Bilbo20230722_
# Bilbo20230722_ tetrode_sample pos 1 valid ti LFP 0-400 Hz   30000          default_differ =BLOB=     =BLOB=     Bilbo20230722_
# Bilbo20230722_ tetrode_sample pos 2 valid ti LFP 0-400 Hz   30000          default_differ =BLOB=     =BLOB=     Bilbo20230722_
# Bilbo20230722_ tetrode_sample pos 3 valid ti LFP 0-400 Hz   30000          default_differ =BLOB=     =BLOB=     Bilbo20230722_
# Bilbo20230722_ tetrode_sample pos 4 valid ti LFP 0-400 Hz   30000          default_differ =BLOB=     =BLOB=     Bilbo20230722_
# Bilbo20230724_ tetrode_sample pos 0 valid ti LFP 0-400 Hz   30000          default_differ =BLOB=     =BLOB=     Bilbo20230724_
# Bilbo20230724_ tetrode_sample pos 1 valid ti LFP 0-400 Hz   30000          default_differ =BLOB=     =BLOB=     Bilbo20230724_
# Bilbo20230724_ tetrode_sample pos 10 valid t LFP 0-400 Hz   30000          default_differ =BLOB=     =BLOB=     Bilbo20230724_
# Bilbo20230724_ tetrode_sample pos 11 valid t LFP 0-400 Hz   30000          default_differ =BLOB=     =BLOB=     Bilbo20230724_
# Bilbo20230724_ tetrode_sample pos 12 valid t LFP 0-400 Hz   30000          default_differ =BLOB=     =BLOB=     Bilbo20230724_
# Bilbo20230724_ tetrode_sample pos 2 valid ti LFP 0-400 Hz   30000          default_differ =BLOB=     =BLOB=     Bilbo20230724_
# Bilbo20230724_ tetrode_sample pos 3 valid ti LFP 0-400 Hz   30000          default_differ =BLOB=     =BLOB=     Bilbo20230724_
#    ...
#  (Total: 59)

# %%
# (LFPArtifactDetectionParameters).fetch()[3]
import numpy as np
import matplotlib.pyplot as plt
artifacts = (LFPArtifactDetection&artifact_key).fetch('artifact_times')[0]

lfp_df = (LFPV1()&key).fetch1_dataframe()
i = 40

ind = np.logical_and(lfp_df.index>artifacts[i][0]-.05,lfp_df.index<artifacts[i][1]+.05)

for j in range (20):
    plt.plot(lfp_df[ind].index,lfp_df[ind][j])

# %%
from spyglass.ripple.v1 import R

# %%
from spyglass.lfp.analysis.v1 import LFPBandV1
LFPBandV1()
# Out:
# *lfp_merge_id  *filter_name   *filter_sampli *nwb_file_name *target_interv *lfp_band_samp analysis_file_ interval_list_ lfp_band_objec
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+
# 001d08a1-5365- Theta 5-11 Hz  1000           Totoro20220602 pos 4 valid ti 100            Totoro20220602 pos 4 valid ti 70d69637-b7d8-
# 00213375-550b- Theta 5-11 Hz  1000           Yoshi20220518_ pos 15 valid t 100            Yoshi20220518_ pos 15 valid t 36efbec9-18ec-
# 004560d5-417b- ripple_150_250 1000           j1620210715_.n 09_s5          1000           j1620210715_2N 09_s5 lfp band 40a2ff51-aa7e-
# 004560d5-417b- theta_5_11     1000           j1620210715_.n 09_s5          1000           j1620210715_RP 09_s5 lfp band f1ac437f-b9b4-
# 006b9516-88d1- ripple_150_250 1000           senor20201103_ 15_s8          1000           senor20201103_ 15_s8 lfp band 0ce4572b-ab3c-
# 006b9516-88d1- theta_5_11     1000           senor20201103_ 15_s8          1000           senor20201103_ 15_s8 lfp band 5bb8e235-7637-
# 0087e094-8238- Fast Gamma 65- 1000           Winnie20220714 pos 9 valid ti 1000           Winnie20220714 pos 9 valid ti d2d0e31a-9023-
# 0087e094-8238- ms_stim_125ms_ 1000           Winnie20220714 pos 9 valid ti 200            Winnie20220714 pos 9 valid ti 455474dd-0a9f-
# 0087e094-8238- Ripple 150-250 1000           Winnie20220714 pos 9 valid ti 1000           Winnie20220714 pos 9 valid ti 0d378b3d-567a-
# 0087e094-8238- Slow Gamma 25- 1000           Winnie20220714 pos 9 valid ti 1000           Winnie20220714 pos 9 valid ti c93c64f1-74cd-
# 0087e094-8238- Theta 5-11 Hz  1000           Winnie20220714 pos 9 valid ti 100            Winnie20220714 pos 9 valid ti 680ca03a-8f87-
# 0093a2c5-d720- ripple_150_250 1000           senor20201118_ 08_r4 noPrePos 1000           senor20201118_ 08_r4 noPrePos 525291cb-c1d3-
#    ...
#  (Total: 8428)
