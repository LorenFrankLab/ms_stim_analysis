# %%
# %load_ext autoreload
# %autoreload 2

import os
import matplotlib.pyplot as plt
# import os
# os.system('source ~/.bashrc')

os.chdir('/home/sambray/Documents/MS_analysis_samsplaying')
print(os.getenv('SPYGLASS_BASE_DIR'))


os.environ
from Analysis.gamma_analysis import gamma_theta_nesting
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /stelmo/nwb

# %% [markdown]
# ## THETA Band Phase

# %%
for animal in ['Frodo','Yoshi']:
    fig = plt.figure(figsize=(12,.5))
    fig.gca().set_title(animal)
    fig.gca().set_xticks([])
    fig.gca().set_yticks([])
    fig.gca().set_frame_on(False)
    for period in [250,165,125,100,80,50]:
        dataset_key = {'optogenetic_protocol':'pulse_train',
                        'period_ms':period,
                        'pulses_per_train':1,
                        "laser_power": 77,
                        "animal":animal,
                        "min_pulse_length":25,
                        "max_pulse_length":42,
                        }

        phase_opto, phase_control, power_opto, power_control = gamma_theta_nesting(dataset_key,
                                                                                #    phase_filter_name=None,
                                                                                   )
    #     break
    # break
# Out:
# datasets: 2
# {'nwb_file_name': 'Frodo20230808_.nwb', 'target_interval_list_name': 'pos 3 valid times'}
# {'nwb_file_name': 'Frodo20230808_.nwb', 'target_interval_list_name': 'pos 3 valid times', 'filter_name': 'Slow Gamma 25-55 Hz'}
# {'nwb_file_name': 'Frodo20230808_.nwb', 'target_interval_list_name': 'pos 3 valid times', 'filter_name': 'Theta 5-11 Hz'}
# linear_limits [28.428666666667496, 75.81733333333331]
# {'nwb_file_name': 'Frodo20230809_.nwb', 'target_interval_list_name': 'pos 11 valid times'}
# {'nwb_file_name': 'Frodo20230809_.nwb', 'target_interval_list_name': 'pos 11 valid times', 'filter_name': 'Slow Gamma 25-55 Hz'}
# {'nwb_file_name': 'Frodo20230809_.nwb', 'target_interval_list_name': 'pos 11 valid times', 'filter_name': 'Theta 5-11 Hz'}
# linear_limits [19.99999999999998, 58.427333333333266]
# datasets: 2
# {'nwb_file_name': 'Frodo20230808_.nwb', 'target_interval_list_name': 'pos 5 valid times'}
# ...

# %% [markdown]
# ## STIMULUS Band Phase

# %%
for animal in ['Frodo','Yoshi']:
    fig = plt.figure(figsize=(12,.5))
    fig.gca().set_title(animal)
    fig.gca().set_xticks([])
    fig.gca().set_yticks([])
    fig.gca().set_frame_on(False)
    for period in [250,165,125,100,80,50]:
        dataset_key = {'optogenetic_protocol':'pulse_train',
                        'period_ms':period,
                        'pulses_per_train':1,
                        "laser_power": 77,
                        "animal":animal,
                        "min_pulse_length":25,
                        "max_pulse_length":42,
                        }

        phase_opto, phase_control, power_opto, power_control = gamma_theta_nesting(dataset_key,
                                                                                   phase_filter_name=None,
                                                                                   )
    #     break
    # break
# Out:
# datasets: 2
# {'nwb_file_name': 'Frodo20230808_.nwb', 'target_interval_list_name': 'pos 3 valid times'}
# {'nwb_file_name': 'Frodo20230808_.nwb', 'target_interval_list_name': 'pos 3 valid times', 'filter_name': 'Slow Gamma 25-55 Hz'}
# {'nwb_file_name': 'Frodo20230808_.nwb', 'target_interval_list_name': 'pos 3 valid times', 'filter_name': 'ms_stim_250ms_period'}
# linear_limits [28.428666666667496, 75.81733333333331]
# {'nwb_file_name': 'Frodo20230809_.nwb', 'target_interval_list_name': 'pos 11 valid times'}
# {'nwb_file_name': 'Frodo20230809_.nwb', 'target_interval_list_name': 'pos 11 valid times', 'filter_name': 'Slow Gamma 25-55 Hz'}
# {'nwb_file_name': 'Frodo20230809_.nwb', 'target_interval_list_name': 'pos 11 valid times', 'filter_name': 'ms_stim_250ms_period'}
# linear_limits [19.99999999999998, 58.427333333333266]
# datasets: 2
# {'nwb_file_name': 'Frodo20230808_.nwb', 'target_interval_list_name': 'pos 5 valid times'}
# ...
