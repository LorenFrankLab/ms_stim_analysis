# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np

from spyglass.common import Session
from spyglass.decoding.v1.clusterless import ClusterlessDecodingV1
from spyglass.decoding.v1.sorted_spikes import SortedSpikesDecodingV1
from spyglass.spikesorting.analysis.v1.group import SortedSpikesGroup

from ms_stim_analysis.Analysis.utils import filter_opto_data, bootstrap_traces
from ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol import OptoStimProtocol
from ms_stim_analysis.Style.style_guide import animal_style


# def bootstrap_traces(data, sample_size=None, statistic=np.mean,
#                      n_boot=1e3 ,conf_interval=95,):
#     if sample_size is None:
#         sample_size = data.shape[0]
#     bootstrap = []
# #     for i in tqdm(range(int(n_boot)),position=0,leave=True):
#     for i in range(int(n_boot)):
#         bootstrap.append(statistic(data[np.random.choice(np.arange(data.shape[0]),sample_size),:],axis=0))
#     bootstrap = np.array(bootstrap)
#     return np.mean(bootstrap,axis=0), [np.percentile(bootstrap,(100-conf_interval)/2,axis=0),
#                                     np.percentile(bootstrap,conf_interval+(100-conf_interval)/2,axis=0)]

def normalized_mean(data,axis=0):
    return np.mean(data/np.mean(data,axis=1)[:,None],axis=axis)
    return np.mean(data,axis=axis)/np.mean()#data,axis=1)[:,None]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Individual animal

# %%
Decoder = SortedSpikesDecodingV1
animal_list = animal_style.index.values
mua_results = {}
track_type = "lineartrack"
animal_list = ["Yoshi"]

for animal in animal_list:
    if animal in mua_results:
        continue

    dataset_key = {
        "animal": animal,
        "targeted_phase": 90,
        "track_type": track_type,
        "min_pulse_length": 20,
    }
    dataset = filter_opto_data(dataset_key)
    mua_plot = []

    nwb_file_name = dataset.fetch("nwb_file_name")[0]
    interval_list_name = dataset.fetch("interval_list_name")[0]
    encoding_tag = ""
    causal_tag = ""

    for nwb_file_name, interval_list_name in zip(
        *dataset.fetch("nwb_file_name", "interval_list_name")
    ):
        key = {
            "nwb_file_name": nwb_file_name,
            "position_group_name": interval_list_name,
            "encoding_interval": interval_list_name + encoding_tag,
        }
        query = (
            (Decoder() & key)
            & f"decoding_param_name LIKE '%{causal_tag}'"
            & "sorted_spikes_group_name NOT LIKE 'manual%'"
        )
        if not query:
            continue
        key = query.fetch1("KEY")

        opto_key = {
            "nwb_file_name": nwb_file_name,
            "interval_list_name": interval_list_name,
        }
        stim, stim_time = OptoStimProtocol().get_stimulus(opto_key)
        test_interval = np.array(
            (OptoStimProtocol() & opto_key).fetch1("test_intervals")
        )
        mua_time = np.arange(np.min(test_interval), np.max(test_interval), 0.002)
        mua = SortedSpikesGroup().get_firing_rate(
            key, mua_time, multiunit=True, smoothing_sigma=0.005
        )

        t_on = stim_time[stim == 1]
        ind_on = np.digitize(t_on, mua_time)
        plot_ind = np.arange(-50, 50, 1)
        mua_plot.extend(
            [
                mua[ind + plot_ind]
                for ind in ind_on
                if (ind + plot_ind[0] >= 0) & (ind + plot_ind[-1] < len(mua))
            ]
        )

    if len(mua_plot) == 0:
        continue
    mua_results[animal] = np.squeeze(mua_plot)
# Out:
# [2025-02-07 10:04:59,216][WARNING]: Skipped checksum for file with hash: 1fb4cf78-9ee6-df68-2734-4b3c6f0f8e42, and path: /stelmo/nwb/raw/Yoshi20220513_.nwb
# datasets: 2
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.5.1 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.4.0 because version 2.6.0-alpha is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.2.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_0' has data shape (31754, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_1' has data shape (35996, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_10' has data shape (26793, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_11' has data shape (36326, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_12' has data shape (26983, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_13' has data shape (36153, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_14' has data shape (26698, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_15' has data shape (37714, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_16' has data shape (26683, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_17' has data shape (38377, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_18' has data shape (25208, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_2' has data shape (26990, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_3' has data shape (36547, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_4' has data shape (26751, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_5' has data shape (36401, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_6' has data shape (27006, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_7' has data shape (36380, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_8' has data shape (27013, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/pynwb/behavior.py:46: UserWarning: SpatialSeries 'series_9' has data shape (36034, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# [2025-02-07 10:05:17,936][WARNING]: Skipped checksum for file with hash: 1fb4cf78-9ee6-df68-2734-4b3c6f0f8e42, and path: /stelmo/nwb/raw/Yoshi20220513_.nwb
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.6.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.3.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."

# %%
fig = plt.figure(figsize=(10, 10))
ax = [fig.gca()]

lo = None
hi = None
for animal in mua_results:
    color = animal_style.loc[animal, "color"]
    mua_plot = mua_results[animal]
    plot_ind = np.arange(-50, 50, 1)

    yy, rng = bootstrap_traces(mua_plot, statistic=normalized_mean, n_boot=1e3)

    if lo is None or lo > rng[0].min():
        lo = rng[0].min()
    if hi is None or hi < rng[1].max():
        hi = rng[1].max()

    ax[0].plot(plot_ind * 2, yy, color=color, label=animal)
    ax[0].fill_between(plot_ind * 2, *rng, facecolor=color, alpha=0.3)

lo = lo * 0.99
hi = hi * 1.01


ax[0].fill_between([0, 40], [lo] * 2, [hi] * 2, color="thistle", alpha=0.5)
ax[0].legend()

for a in ax:
    a.spines[["top", "right"]].set_visible(False)
plt.xlabel("time since stim on (ms)")
ax[0].set_ylabel("normalized MUA")
plt.xlim(-60, 60)
plt.rcParams["svg.fonttype"] = "none"
# fig.savefig('/home/sambray/Documents/MS_analysis_samsplaying/Plots/fens_2024/mua_lineartrack_90_individual.svg',format='svg')

# %% [markdown]
# # group transfected and control

# %%
Decoder = SortedSpikesDecodingV1
animal_list = animal_style.index.values
mua_results = {}

for transfected in [True, False]:
    dataset_key = {
        "targeted_phase": 90,
        "track_type": "lineartrack",
        "min_pulse_length": 20,
        "transfected": transfected,
    }
    dataset = filter_opto_data(dataset_key)
    mua_plot = []
    encoding_tag = ""
    causal_tag = ""
    n_units = 0

    for nwb_file_name, interval_list_name in zip(
        *dataset.fetch("nwb_file_name", "interval_list_name")
    ):
        key = {
            "nwb_file_name": nwb_file_name,
            "position_group_name": interval_list_name,
            "encoding_interval": interval_list_name + encoding_tag,
        }
        query = (
            (Decoder() & key)
            & f"decoding_param_name LIKE '%{causal_tag}'"
            & "sorted_spikes_group_name NOT LIKE 'manual%'"
        )
        if not query:
            continue
        key = query.fetch1("KEY")

        opto_key = {
            "nwb_file_name": nwb_file_name,
            "interval_list_name": interval_list_name,
        }
        stim, stim_time = OptoStimProtocol().get_stimulus(opto_key)
        test_interval = np.array(
            (OptoStimProtocol() & opto_key).fetch1("test_intervals")
        )
        mua_time = np.arange(np.min(test_interval), np.max(test_interval), 0.002)
        mua = SortedSpikesGroup().get_firing_rate(
            key, mua_time, multiunit=True, smoothing_sigma=0.005
        )
        n_units += len(SortedSpikesGroup.fetch_spike_data(key))

        t_on = stim_time[stim == 1]
        ind_on = np.digitize(t_on, mua_time)
        plot_ind = np.arange(-50, 50, 1)
        mua_plot.extend(
            [
                mua[ind + plot_ind]
                for ind in ind_on
                if (ind + plot_ind[0] >= 0) & (ind + plot_ind[-1] < len(mua))
            ]
        )

    if transfected:
        mua_results["transfected"] = np.squeeze(mua_plot)
    else:
        mua_results["control"] = np.squeeze(mua_plot)
    print("transfected" if transfected else "control")
    print("total_units", n_units)
    print("total_stimuli", len(mua_plot))
# Out:
# [2025-08-28 15:13:18,621][WARNING]: Skipped checksum for file with hash: 1f5c50a7-0065-fa56-18eb-45182d0fa2f5, and path: /stelmo/nwb/raw/Frodo20230810_.nwb
# datasets: 11
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# [15:17:05][WARNING] Spyglass: No spike object found for ae1ea40f-5f68-4832-979d-9d970db63509
# [15:17:05][WARNING] Spyglass: No spike object found for e168c49e-4f20-dad4-3a78-016efb9317db
# [15:17:05][WARNING] Spyglass: No spike object found for 6782837f-4395-2d76-75ff-dee458d527ff
# [15:17:05][WARNING] Spyglass: No spike object found for a52584e7-e94d-36e9-1205-e34d54ee2a27
# [15:17:05][WARNING] Spyglass: No spike object found for 37b700b2-5841-2719-5121-783573be1fcb
# [15:17:05][WARNING] Spyglass: No spike object found for e72e35d6-1ae1-8677-42d7-4c0b79a908fc
# [15:17:05][WARNING] Spyglass: No spike object found for 866be067-9d33-6f57-9765-fc567c7209b5
# [15:17:21][WARNING] Spyglass: No spike object found for ae1ea40f-5f68-4832-979d-9d970db63509
# [15:17:21][WARNING] Spyglass: No spike object found for e168c49e-4f20-dad4-3a78-016efb9317db
# [15:17:21][WARNING] Spyglass: No spike object found for 6782837f-4395-2d76-75ff-dee458d527ff
# [15:17:21][WARNING] Spyglass: No spike object found for a52584e7-e94d-36e9-1205-e34d54ee2a27
# [15:17:21][WARNING] Spyglass: No spike object found for 37b700b2-5841-2719-5121-783573be1fcb
# [15:17:21][WARNING] Spyglass: No spike object found for e72e35d6-1ae1-8677-42d7-4c0b79a908fc
# [15:17:21][WARNING] Spyglass: No spike object found for 866be067-9d33-6f57-9765-fc567c7209b5
# [2025-08-28 15:17:21,868][WARNING]: Skipped checksum for file with hash: 6d808fc5-4451-72e0-8008-5d012e52bddf, and path: /stelmo/nwb/raw/Frodo20230811_.nwb
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# [15:21:08][WARNING] Spyglass: No spike object found for 5881328a-6b5c-b654-d5dc-9a33a4b5e2fb
# [15:21:08][WARNING] Spyglass: No spike object found for d044357a-e4ec-7a8b-61e8-143b6f75d094
# [15:21:08][WARNING] Spyglass: No spike object found for 9c5fa8c0-59f6-f14c-3f39-074463db3385
# [15:21:08][WARNING] Spyglass: No spike object found for e6be2418-772d-e974-0af6-25adefe45266
# [15:21:08][WARNING] Spyglass: No spike object found for dbff5f94-9459-1b4b-d933-e81df1c49396
# [15:21:08][WARNING] Spyglass: No spike object found for 9c9d5973-ae91-e024-848d-21a9ce0b1545
# [15:21:08][WARNING] Spyglass: No spike object found for b30ed29d-40d6-3d87-d47f-9fb5985763fc
# [15:21:08][WARNING] Spyglass: No spike object found for d7f06bc7-73a3-c8cc-ecd4-27b02fb5ba38
# [15:21:24][WARNING] Spyglass: No spike object found for 5881328a-6b5c-b654-d5dc-9a33a4b5e2fb
# [15:21:24][WARNING] Spyglass: No spike object found for d044357a-e4ec-7a8b-61e8-143b6f75d094
# [15:21:24][WARNING] Spyglass: No spike object found for 9c5fa8c0-59f6-f14c-3f39-074463db3385
# [15:21:24][WARNING] Spyglass: No spike object found for e6be2418-772d-e974-0af6-25adefe45266
# [15:21:24][WARNING] Spyglass: No spike object found for dbff5f94-9459-1b4b-d933-e81df1c49396
# [15:21:24][WARNING] Spyglass: No spike object found for 9c9d5973-ae91-e024-848d-21a9ce0b1545
# [15:21:24][WARNING] Spyglass: No spike object found for b30ed29d-40d6-3d87-d47f-9fb5985763fc
# [15:21:24][WARNING] Spyglass: No spike object found for d7f06bc7-73a3-c8cc-ecd4-27b02fb5ba38
# [2025-08-28 15:21:24,700][WARNING]: Skipped checksum for file with hash: 7ed2c389-5010-5a81-4934-91cc2b37f8d4, and path: /stelmo/nwb/raw/Totoro20220607_.nwb
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.4.0, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_0' has data shape (43224, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_1' has data shape (36123, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_10' has data shape (30860, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_11' has data shape (36039, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_12' has data shape (33592, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_13' has data shape (36129, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_14' has data shape (50893, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_15' has data shape (37172, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_16' has data shape (60057, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_17' has data shape (36170, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_18' has data shape (9697, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_2' has data shape (59161, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_3' has data shape (34983, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_4' has data shape (51408, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_5' has data shape (36270, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_6' has data shape (46981, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_7' has data shape (35688, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_8' has data shape (36787, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/pynwb/behavior.py:58: UserWarning: SpatialSeries 'series_9' has data shape (35607, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# [2025-08-28 15:25:15,349][WARNING]: Skipped checksum for file with hash: 7ed2c389-5010-5a81-4934-91cc2b37f8d4, and path: /stelmo/nwb/raw/Totoro20220607_.nwb
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# ...
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# [15:53:11][WARNING] Spyglass: No spike object found for b342c851-9406-fbb1-2984-3d85db182ba6
# [15:53:11][WARNING] Spyglass: No spike object found for 3de0b8ab-9171-108e-fc60-670fe74ddfd5
# [15:53:11][WARNING] Spyglass: No spike object found for 7961e1cb-2bc3-b133-8600-4ef2351f7065
# [15:53:11][WARNING] Spyglass: No spike object found for 50cf15af-488a-dd02-d319-7491e965a6ad
# [15:53:11][WARNING] Spyglass: No spike object found for 6e44d442-8b9d-ace3-da80-b6c995241013
# [15:53:11][WARNING] Spyglass: No spike object found for 9f303252-a48a-9826-1014-b6222d5a29a8
# [15:53:40][WARNING] Spyglass: No spike object found for b342c851-9406-fbb1-2984-3d85db182ba6
# [15:53:40][WARNING] Spyglass: No spike object found for 3de0b8ab-9171-108e-fc60-670fe74ddfd5
# [15:53:40][WARNING] Spyglass: No spike object found for 7961e1cb-2bc3-b133-8600-4ef2351f7065
# [15:53:40][WARNING] Spyglass: No spike object found for 50cf15af-488a-dd02-d319-7491e965a6ad
# [15:53:40][WARNING] Spyglass: No spike object found for 6e44d442-8b9d-ace3-da80-b6c995241013
# [15:53:40][WARNING] Spyglass: No spike object found for 9f303252-a48a-9826-1014-b6222d5a29a8
# [2025-08-28 15:53:40,660][WARNING]: Skipped checksum for file with hash: 1fb4cf78-9ee6-df68-2734-4b3c6f0f8e42, and path: /stelmo/nwb/raw/Yoshi20220513_.nwb
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/sambray/mambaforge-pypy3/envs/ms_stim_analysis/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.6.0-alpha, loaded version: 2.8.0
# ndx-franklab-novela - cached version: 0.1.0, loaded version: 0.2.1
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# [15:56:39][WARNING] Spyglass: No spike object found for 62d37dff-00c7-2dd4-2585-47f3376dab43
# [15:56:39][WARNING] Spyglass: No spike object found for 2a89b24d-408e-a3af-1249-e8164a37fa02
# [15:56:39][WARNING] Spyglass: No spike object found for dbe05041-e74a-ca4c-c0b5-659ef7b9e8df
# [15:56:39][WARNING] Spyglass: No spike object found for 4a333027-a058-8947-a4aa-9d888b2e19ae
# [15:56:39][WARNING] Spyglass: No spike object found for f57f4ecb-f2ac-5ab1-dda8-4fa2b004489d
# [15:56:39][WARNING] Spyglass: No spike object found for 81becd19-8ae6-7335-fc1e-71132d826cf3
# [15:56:39][WARNING] Spyglass: No spike object found for 33d1d52e-d5db-bf1b-0bf6-0bec905622cd
# [15:56:39][WARNING] Spyglass: No spike object found for ee19a527-e02b-36e5-11f6-4c8bbbcc03d5
# [15:56:39][WARNING] Spyglass: No spike object found for d33707ad-d620-b44e-f8a3-374179da042a
# [15:56:39][WARNING] Spyglass: No spike object found for 65b2ed2c-2ea7-38cd-1a61-760392a6ed1f
# [15:57:09][WARNING] Spyglass: No spike object found for 62d37dff-00c7-2dd4-2585-47f3376dab43
# [15:57:09][WARNING] Spyglass: No spike object found for 2a89b24d-408e-a3af-1249-e8164a37fa02
# [15:57:09][WARNING] Spyglass: No spike object found for dbe05041-e74a-ca4c-c0b5-659ef7b9e8df
# [15:57:09][WARNING] Spyglass: No spike object found for 4a333027-a058-8947-a4aa-9d888b2e19ae
# [15:57:09][WARNING] Spyglass: No spike object found for f57f4ecb-f2ac-5ab1-dda8-4fa2b004489d
# [15:57:09][WARNING] Spyglass: No spike object found for 81becd19-8ae6-7335-fc1e-71132d826cf3
# [15:57:09][WARNING] Spyglass: No spike object found for 33d1d52e-d5db-bf1b-0bf6-0bec905622cd
# [15:57:09][WARNING] Spyglass: No spike object found for ee19a527-e02b-36e5-11f6-4c8bbbcc03d5
# [15:57:09][WARNING] Spyglass: No spike object found for d33707ad-d620-b44e-f8a3-374179da042a
# [15:57:09][WARNING] Spyglass: No spike object found for 65b2ed2c-2ea7-38cd-1a61-760392a6ed1f
# control
# total_units 499
# total_stimuli 4815

# %%
from ms_stim_analysis.Style.style_guide import transfection_style

fig = plt.figure(figsize=(10, 10))
ax = [fig.gca()]

lo = None
hi = None
for animal in mua_results:
    if animal == "non-transfected":
        color = transfection_style["control"]
    else:
        color = transfection_style[animal]
    mua_plot = mua_results[animal]
    plot_ind = np.arange(-50, 50, 1)
    # add mua
    yy = np.squeeze(np.mean(mua_plot, axis=0)) / np.mean(mua_plot)
    rng = np.squeeze(
        np.std(mua_plot / np.mean(mua_plot), axis=0)
    )  # /np.sqrt(mua_plot.shape[0])
    rng = [yy - rng, yy + rng]

    yy, rng = bootstrap_traces(mua_plot, statistic=normalized_mean, n_boot=1e3)

    if lo is None or lo > rng[0].min():
        lo = rng[0].min()
    if hi is None or hi < rng[1].max():
        hi = rng[1].max()

    ax[0].plot(plot_ind * 2, yy, color=color, label=animal)
    ax[0].fill_between(plot_ind * 2, *rng, facecolor=color, alpha=0.3)

lo = lo * 0.99
hi = hi * 1.01


ax[0].fill_between([0, 40], [lo] * 2, [hi] * 2, color="thistle", alpha=0.5)
ax[0].legend()

for a in ax:
    a.spines[["top", "right"]].set_visible(False)
plt.xlabel("time since stim on (ms)")
ax[0].set_ylabel("normalized MUA")
ax[0].set_ylim(lo, hi - 0.001)
plt.xlim(-60, 60)

plt.rcParams["svg.fonttype"] = "none"
fig.savefig(
    "../Figures/Fig_2/Fig_2c_mua_lineartrack_90_stim_response.svg", format="svg"
)
