# %%
# import os
# os.chdir
# from Analysis.spiking_autocorrelegram import unit_autocorrelegram
# from Analysis.utils import filter_opto_data

from spyglass.spikesorting.analysis.v1.group import SortedSpikesGroup
from spyglass.decoding.v1.sorted_spikes import SortedSpikesDecodingV1
from spyglass.common import IntervalList
import os

import numpy as np
import matplotlib.pyplot as plt

os.chdir("/home/sambray/Documents/MS_analysis_samsplaying")

# %%
from ms_opto_stim_protocol import OptoStimProtocol

OptoStimProtocol & key & {"interval_list_name": pos_interval}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from ms_opto_stim_protocol import OptoStimProtocol
# ----> 3 OptoStimProtocol & key & {"interval_list_name": pos_interval}
#
# NameError: name 'key' is not defined

# %%
nwb_file_name = "Winnie20220717_.nwb"
pos_interval = "pos 3 valid times"

# nwb_file_name = "Yoshi20220513_.nwb"
# pos_interval = "pos 3 valid times"

place_field_list = []
epoch_fractions = []
for encoding in [
    "_opto_control_interval",
    "_opto_test_interval",
    "_stimulus_on_interval",
]:

    key = {
        "nwb_file_name": nwb_file_name,
    }
    decode_key = {**key, "encoding_interval": pos_interval + encoding}

    decoding_query = (
        SortedSpikesDecodingV1
        & decode_key
        & "sorted_spikes_group_name NOT LIKE 'manual_full_day'"
    )

    fit_model = decoding_query.fetch_model()

    # get place fields
    place_field = list(fit_model.encoding_model_.values())[0]["place_fields"]
    place_field_list.append(place_field)

    bin_centers = list(fit_model.encoding_model_.values())[0][
        "environment"
    ].place_bin_centers_

    encoding_interval = decoding_query.fetch1("encoding_interval")
    encoding_times = (
        IntervalList & key & {"interval_list_name": encoding_interval}
    ).fetch1("valid_times")
    encoding_length = np.sum(np.diff(encoding_times, axis=1))  # in seconds, not ms
    epoch_times = (IntervalList & key & {"interval_list_name": pos_interval}).fetch1(
        "valid_times"
    )
    epoch_length = np.sum(np.diff(epoch_times, axis=1))  # in seconds, not ms

    epoch_fractions.append(encoding_length / epoch_length)

# %%
# qq = list(fit_model.encoding_model_.values())[0]["place_fields"]

# qq.shape

# qq.sum(axis=0)
type(list(fit_model.encoding_model_.values())[0])
# Out:
# dict

# %%
list(fit_model.encoding_model_.values())[0]["environment"].place_bin_centers_
# Out:
# array([[  0.99197367],
#        [  2.97592101],
#        [  4.95986835],
#        [  6.94381569],
#        [  8.92776303],
#        [ 10.91171037],
#        [ 12.89565771],
#        [ 14.87960505],
#        [ 16.86355239],
#        [ 18.84749973],
#        [ 20.83144707],
#        [ 22.81539441],
#        [ 24.79934175],
#        [ 26.78328909],
#        [ 28.76723643],
#        [ 30.75118377],
#        [ 32.73513111],
#        [ 34.71907845],
#        [ 36.70302579],
#        [ 38.68697314],
#        [ 40.67092048],
#        [ 42.65486782],
#        [ 44.63881516],
#        [ 46.6227625 ],
#        [ 48.60670984],
#        [ 50.59065718],
#        [ 52.57460452],
#        [ 54.55855186],
#        [ 56.5424992 ],
#        [ 58.52644654],
#        [ 60.51039388],
#        [ 62.49434122],
#        [ 64.47828856],
#        [ 66.4622359 ],
#        [ 68.44618324],
#        [ 70.43013058],
#        [ 72.41407792],
#        [ 74.39802526],
#        [ 76.3819726 ],
#        [ 78.36591994],
# ...

# %%
place_field_list[0].shape, place_field_list[1].shape
# Out:
# ((36, 69), (36, 69))

# %%
import matplotlib.pyplot as plt
import numpy as np

bins = np.linspace(-100, 100, 200)
binned_vals = [[[] for i in range(bins.size - 1)] for _ in place_field_list]

for i in range(place_field_list[0].shape[0]):
    loc = np.argmax(place_field_list[0][i])
    if loc == 0 or loc == len(place_field_list[0][i]):
        continue
    xx = np.arange(0, len(place_field_list[0][i])) - loc
    norm = np.max(place_field_list[0][i])
    plt.plot(xx, place_field_list[0][i] / norm, label="control", color="b", alpha=0.2)
    plt.plot(xx, place_field_list[1][i] / norm, label="test", color="r", alpha=0.2)

    bin_index = np.digitize(xx, bins) - 1
    missing = np.append(
        np.arange(0, bin_index.min()), np.arange(bin_index.max() + 1, bins.size - 1)
    )

    for k, data in enumerate(place_field_list):
        for j in range(len(bin_index)):
            binned_vals[k][bin_index[j]].append(data[i][j] / data[i].sum())
        for j in missing:
            binned_vals[k][j].append(0)
    # for j in range(len(bin_index)):
    #     binned_vals[0][bin_index[j]].append(place_field_list[0][i][j]/norm)
    #     binned_vals[1][bin_index[j]].append(place_field_list[1][i][j]/norm)
    # plt.legend()
    # plt.show()

plt.ylim(0, 2)
# Out:
# (0.0, 2.0)

# %%
from Style.style_guide import interval_style

for data, color in zip(
    binned_vals, [interval_style["control"], interval_style["test"], "grey"]
):
    for d in data:
        if not d:
            d.append(0)
    mid = [np.median(data[i]) for i in range(len(binned_vals[0]))]
    lo = [np.percentile(data[i], 25) for i in range(len(binned_vals[0]))]
    hi = [np.percentile(data[i], 75) for i in range(len(binned_vals[0]))]
    plt.plot(bins[1:], mid, color=color)
    plt.fill_between(bins[1:], lo, hi, alpha=0.3, facecolor=color)

    # plt.xlim(-50,50)

    plt.xlabel("Bin distance from control interval peak")
    plt.ylabel("Normalized firing rate")
    plt.title(key)

# %%
def alpha_blending(hex_color, alpha):
    """alpha blending as if on the white background."""
    import matplotlib

    foreground_tuple = matplotlib.colors.hex2color(hex_color)
    foreground_arr = np.array(foreground_tuple)
    final = tuple((1.0 - alpha) + foreground_arr * alpha)
    return final

# %%
SortedSpikesDecodingV1()
# Out:
# *nwb_file_name *unit_filter_p *sorted_spikes *position_grou *decoding_para *encoding_inte *decoding_inte *estimate_deco results_pa classifier
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# Bilbo20230724_ default_exclus 04_lineartrack pos 3 valid ti ms_lineartrack pos 3 valid ti pos 3 valid ti 0              =BLOB=     =BLOB=
# Bilbo20230724_ default_exclus 04_lineartrack pos 3 valid ti ms_lineartrack pos 3 valid ti pos 3 valid ti 0              =BLOB=     =BLOB=
# Bilbo20230724_ default_exclus 04_lineartrack pos 3 valid ti ms_lineartrack pos 3 valid ti pos 3 valid ti 0              =BLOB=     =BLOB=
# Bilbo20230724_ default_exclus 04_lineartrack pos 3 valid ti ms_lineartrack pos 3 valid ti pos 3 valid ti 0              =BLOB=     =BLOB=
# Bilbo20230724_ default_exclus 06_lineartrack pos 5 valid ti ms_lineartrack pos 5 valid ti pos 5 valid ti 0              =BLOB=     =BLOB=
# ...

# %%
from Style.style_guide import interval_style

place_field_list[0].shape
loc = np.array([0.4, 0.5, 0.8])  # Winnie's
loc = np.array([0.4, 0.55, 0.75])  # Yoshi's
ind_max = np.argmax(place_field_list[0], axis=1)
loc = loc * ind_max.max()

loc = np.array([np.argmin(np.abs(ind_max - l)) for l in loc])

# loc = (len(place_field_list[0][0])*loc).astype(int)
# ind_sort = np.argsort(np.argmax(place_field_list[0],axis=1))
# loc = ind_sort[loc]

fig, ax = plt.subplots(nrows=2, sharex=1, sharey=0, figsize=(5, 3))
colors = [interval_style["control"], interval_style["test"], "grey"]
colors = [alpha_blending(c, 0.3) for c in colors]
labels = ["control interval", "test interval", "stimulus on times"]
for i, fields in enumerate(place_field_list[:-1]):
    data = fields[loc] * 500
    data = data / data.mean(axis=1)[:, None]  # normalize to mean firing rate
    # data = data/data.mean(axis=1)[:,None]
    ax[i].plot(
        bin_centers,
        data.T,
    )

    ax[i].set_facecolor(colors[i])
    # ax[i].set_alpha(.1)
    ax[i].text(5, data.max() * 0.9, labels[i])
    # ax[i].set_xlim(bin_centers.min(),bin_centers.max())

for a in ax:
    a.spines[
        [
            "right",
            "top",
        ]
    ].set_visible(False)
    # a.set_yticks([])

# for a in ax[:-1]:
# a.set_xticks([])

ax[-1].set_xlim(bin_centers.min(), bin_centers.max())
ax[-1].set_xlabel("Position (cm)")
# ax[-1].set_ylabel("$f_{position}$ / $f_{average}$",va="bottom",ha="left")
ax[-1].set_ylabel("Firing rate (Hz)", va="bottom", ha="left")

plt.subplots_adjust(wspace=0, hspace=0.01)
plt.suptitle(key)

plt.rcParams["svg.fonttype"] = "none"
plt.rcParams["font.family"] = "Arial"
# fig.savefig("Plots/Fig2G_yoshi.svg",format="svg")
# fig.savefig("/home/sambray/Documents/MS_analysis_samsplaying/Figures202507/Fig2_place_field_stability_original_fields_winnie.svg",format="svg")
fig.savefig(
    "/home/sambray/Documents/MS_analysis_samsplaying/Figures202507/Fig2_place_field_stability_winnie_fixed_scale.svg",
    format="svg",
)

# %%
from spyglass.common import IntervalList

encoding_interval = decoding_query.fetch1("encoding_interval")
encoding_times = (
    IntervalList & key & {"interval_list_name": encoding_interval}
).fetch1("valid_times")
encoding_length = np.sum(np.diff(encoding_times, axis=1))  # in seconds, not ms
epoch_times = (IntervalList & key & {"interval_list_name": pos_interval}).fetch1(
    "valid_times"
)
epoch_length = np.sum(np.diff(epoch_times, axis=1))  # in seconds, not ms

encoding_length / epoch_length

# np.mean(place_field_list[0].max(axis=1)), np.mean(place_field_list[1].max(axis=1))
# Out:
# 0.0230404615582472

# %%
# ind_max = np.argmax(place_field_list[0],axis=1)
# ind_sort = np.argsort(ind_max)
# ind_max[ind_sort]
encoding_model = fit_model.encoding_model_.values()  # [0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 5
#       1 # ind_max = np.argmax(place_field_list[0],axis=1)
#       2 # ind_sort = np.argsort(ind_max)
#       3 # ind_max[ind_sort]
#       4 encoding_model = fit_model.encoding_model_.values()#[0]
# ----> 5 fit_model._encoding_model_data
#
# AttributeError: 'SortedSpikesDetector' object has no attribute '_encoding_model_data'

# %%
place_field_list[0][i][j]
binned_vals  # [0]#[bin_index[j]]
interval_style
# Out:
# {'test': '#DA70D6', 'control': '#7BC8F6'}

# %%
SortedSpikesDecodingV1 & key & f"encoding_interval LIKE '{pos_interval}%'"
# Out:
# *nwb_file_name *unit_filter_p *sorted_spikes *position_grou *decoding_para *encoding_inte *decoding_inte *estimate_deco results_pa classifier
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# Winnie20220717 default_exclus 04_lineartrack pos 3 valid ti ms_lineartrack pos 3 valid ti pos 3 valid ti 0              =BLOB=     =BLOB=
# Winnie20220717 default_exclus 04_lineartrack pos 3 valid ti ms_lineartrack pos 3 valid ti pos 3 valid ti 0              =BLOB=     =BLOB=
# Winnie20220717 default_exclus 04_lineartrack pos 3 valid ti ms_lineartrack pos 3 valid ti pos 3 valid ti 0              =BLOB=     =BLOB=
# Winnie20220717 default_exclus 04_lineartrack pos 3 valid ti ms_lineartrack pos 3 valid ti pos 3 valid ti 0              =BLOB=     =BLOB=
# Winnie20220717 default_exclus manual_full_da pos 3 valid ti ms_lineartrack pos 3 valid ti pos 3 valid ti 0              =BLOB=     =BLOB=
# ...
