# %%
# %load_ext autoreload
# %autoreload 2

from ms_stim_analysis.AnalysisTables.location_times import LocationTimesParams, LocationTimesSelection, LocationTimes
import numpy as np
from spyglass.position.position_merge import PositionOutput
# Out:
# [2025-08-27 09:20:02,686][INFO]: DataJoint 0.14.6 connected to sambray@lmf-db.cin.ucsf.edu:3306

# %%
# # Logging for database export. Not necessary for replication

# from spyglass.common.common_usage import Export, ExportSelection
# paper_key = {"paper_id":"ms_stim_analysis"}

# analysis_id = "choice_point_occupancy"
# ExportSelection().start_export(**paper_key, analysis_id=analysis_id)
# Out:
# [09:21:55][INFO] Spyglass: Resuming {'export_id': 41}

# %% [markdown]
# # Analyze

# %%
from ms_stim_analysis.Analysis.utils import filter_opto_data, violin_scatter
from spyglass.common import TaskEpoch, PositionIntervalMap
from ms_stim_analysis.Style.style_guide import animal_style
from spyglass.common import interval_list_intersect
import matplotlib.pyplot as plt
from ms_stim_analysis.AnalysisTables.trial_intervals import TrialIntervals

# from spyglass.position.v1 import

# %%
# animal = 'Bilbo'
animal_list = list(animal_style.index)
animal_list = [a for a in animal_list if a not in ["Odins", "control", "transfected"]]

animal_list = ["control", "transfected"]

pos_list = []
labels_list = []
fig = plt.figure()
ax = fig.add_subplot(111)
results = {animal: {} for animal in animal_list}
for i_trial, trial_type in enumerate(["inbound", "outbound"]):
    for i, animal in enumerate(animal_list):
        dataset_key = {
            "animal": animal,
            "track_type": "early_wtrack",
            "targeted_phase": 90,
        }
        dataset = filter_opto_data(dataset_key)

        if not dataset:
            continue
        occupancy_lengths = []
        for key in dataset.fetch("KEY"):
            epoch_key = {
                "nwb_file_name": key["nwb_file_name"],
                "position_interval_name": key["interval_list_name"],
            }
            epoch = ((PositionIntervalMap() & epoch_key) * TaskEpoch()).fetch1("epoch")

            query = PositionOutput.DLCPosV1() & key & {"epoch": epoch}
            if not query:
                continue
            intervals = (LocationTimes() & query.fetch(as_dict=True)).fetch1(
                "intervals"
            )

            trial_query = TrialIntervals() & {
                "nwb_file_name": key["nwb_file_name"],
                "epoch": epoch,
            }
            trial_interval = None
            if trial_type == "outbound":
                # if not trial_query:
                #     continue
                trial_interval = trial_query.fetch1("outbound_trial_intervals")
            elif trial_type == "inbound":
                # if not trial_query:
                #     continue
                trial_interval = trial_query.fetch1("inbound_trial_intervals")

            if not len(trial_interval):
                continue
            intervals = interval_list_intersect(intervals, trial_interval)
            occupancy_lengths.extend([en - st for st, en in intervals])

        results[animal][trial_type] = occupancy_lengths
        pos = i * 1.2 + i_trial * 0.5
        violin_scatter(
            occupancy_lengths,
            pos=pos,
            color=animal_style.loc[animal, "color"],
            mark_mean=True,
        )
        print(f"{animal} {trial_type}: {len(occupancy_lengths)}")
        plt.scatter(
            [pos],
            [np.mean(occupancy_lengths)],
            color=animal_style.loc[animal, "color"],
            edgecolor="k",
            label=animal + " " + trial_type,
        )
        pos_list.append(pos)
        labels_list.append(animal + " " + trial_type)


plt.ylim(0, 10)
plt.xticks(pos_list, labels_list, rotation=-90)
plt.ylabel("Choice point occupancy (s)")
ax.spines[["top", "right"]].set_visible(False)

plt.rcParams["svg.fonttype"] = "none"
fig.savefig("../Figures/Fig_3/Fig_3f_choice_point_occupancy.svg")
# Out:
# [09:28:16][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolClosedLoop'>
# datasets: 42
# [09:28:20][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:22][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:24][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:26][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:27][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:29][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:30][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:32][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:35][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:37][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:39][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:41][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:45][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:48][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:50][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:53][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:54][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:56][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:58][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:28:59][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:01][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:03][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:04][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:06][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:07][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:10][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:12][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:13][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:15][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:17][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:19][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:20][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:22][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:25][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:27][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:29][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:32][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:34][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:35][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:37][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:37][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolClosedLoop'>
# control inbound: 1089
# datasets: 44
# [09:29:44][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:47][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:50][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:53][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:56][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:29:59][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:01][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:04][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:07][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:10][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:13][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:15][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:18][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:19][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:22][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:24][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:26][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:27][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:29][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:30][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:31][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:33][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:34][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:35][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:37][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:38][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:39][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:42][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:44][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:46][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:48][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:50][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:53][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:55][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:30:57][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:00][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:03][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:05][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:07][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:09][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:11][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:13][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:15][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:16][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:16][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolClosedLoop'>
# transfected inbound: 1162
# datasets: 42
# [09:31:20][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:22][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:23][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:24][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:26][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:27][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:28][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:29][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:30][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:32][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:33][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:34][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:35][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:37][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:38][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:39][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:41][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:42][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:45][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:46][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:47][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:50][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:50][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:51][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:52][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:54][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:55][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:56][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:58][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:31:59][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:01][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:02][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:03][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:05][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:06][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:09][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:10][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:11][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:13][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:13][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolClosedLoop'>
# control outbound: 1086
# datasets: 44
# [09:32:17][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:19][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:22][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:24][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:26][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:28][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:30][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:33][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:35][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:37][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:39][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:41][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:44][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:46][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:48][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:50][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:51][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:52][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:52][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:53][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:54][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:54][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:56][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:56][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:57][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:58][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:32:59][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:33:01][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:33:02][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:33:03][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:33:05][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:33:06][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:33:08][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:33:09][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:33:11][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:33:12][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:33:14][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:33:15][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:33:17][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:33:18][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [09:33:20][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# transfected outbound: 1148

# %%
x_locs = []
x_labels = []

fig, ax = plt.subplots()
for i, animal in enumerate(results):
    for j, trial_type in enumerate(results[animal]):
        c = animal_style.loc[animal, "color"]
        x = 2 * i + j * 0.6
        plt.boxplot(
            results[animal][trial_type],
            positions=[x],
            widths=0.4,
            patch_artist=True,
            showmeans=False,
            # showmedians=False,
            boxprops=dict(facecolor=c, alpha=0.5, edgecolor=c, lw=1.5),
            capprops=dict(color=c),
            whiskerprops=dict(color=c, lw=2),
            flierprops=dict(color=c, markeredgecolor=c),
            medianprops=dict(color=c),
            notch=True,
            showfliers=False,
        )
        print(
            f"{animal} {trial_type}: {np.round(np.percentile(results[animal][trial_type], [25,50,75]),3)}"
        )
        x_locs.append(x)
        x_labels.append(animal + " " + trial_type)
plt.xticks(x_locs, x_labels, rotation=-90)
plt.ylabel("Choice point occupancy (s)")
ax.spines[["top", "right"]].set_visible(False)
plt.rcParams["svg.fonttype"] = "none"
fig.savefig("./Figures_20250501/choice_point_occupancy_boxplot.svg")
# Out:
# control inbound: [0.7   0.8   1.067]
# control outbound: [0.767 1.033 1.7  ]
# transfected inbound: [0.867 1.033 1.458]
# transfected outbound: [1.    1.5   2.533]

# %% [markdown]
# ### independent ttests

# %%
from scipy.stats import ttest_ind

for animal in results:
    print(animal + ": inbound vs outbound")
    print(
        ttest_ind(
            results[animal]["inbound"], results[animal]["outbound"], equal_var=False
        )[1]
    )

for trial_type in ["inbound", "outbound"]:
    print(trial_type + ": control vs transfected")
    print(
        ttest_ind(
            results["control"][trial_type],
            results["transfected"][trial_type],
            equal_var=False,
        )[1]
    )
# Out:
# control: inbound vs outbound
# 1.9788381784346803e-05
# transfected: inbound vs outbound
# 1.4945074039237271e-21
# inbound: control vs transfected
# 0.010072511211836192
# outbound: control vs transfected
# 1.081720354456e-15

# %% [markdown]
# ### Mixed linear model

# %%
import statsmodels.api as sms
import pandas as pd

model_df = []
for i, animal in enumerate(results.keys()):
    for trial_type in ["inbound", "outbound"]:
        data = results[animal][trial_type]
        for d in data:
            model_df.append(
                {
                    "Animal": i,
                    "Treatment": (
                        "transfected"
                        if animal_style.loc[animal, "background"] == "indianred"
                        else "control"
                    ),
                    "Trial_Type": trial_type,
                    "Score": d,
                }
            )


model_df = pd.DataFrame(model_df)

from statsmodels.formula.api import mixedlm

# Convert the 'Treatment' column to a categorical variable
model_df["Treatment"] = model_df["Treatment"].astype("category")
model_df["Trial_Type"] = model_df["Trial_Type"].astype("category")
# model_df['Animal'] = model_df['Treatment'].astype('category')

# Fit the mixed-effects model
model = mixedlm("Score ~ Treatment * Trial_Type", model_df, groups=model_df["Animal"])
result = model.fit()

# Print the summary of the model
print(result.summary())
result.pvalues
# Out:
#                          Mixed Linear Model Regression Results
# ========================================================================================
# Model:                        MixedLM           Dependent Variable:           Score
# No. Observations:             4485              Method:                       REML
# No. Groups:                   2                 Scale:                        2.6355
# Min. group size:              2175              Log-Likelihood:               -8543.4770
# Max. group size:              2310              Converged:                    Yes
# Mean group size:              2242.5
# ----------------------------------------------------------------------------------------
#                                                 Coef. Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                       1.218    1.624 0.750 0.453 -1.965  4.401
# Treatment[T.transfected]                        0.178    2.297 0.078 0.938 -4.323  4.680
# Trial_Type[T.outbound]                          0.292    0.070 4.199 0.000  0.156  0.429
# Treatment[T.transfected]:Trial_Type[T.outbound] 0.370    0.097 3.810 0.000  0.179  0.560
# Group Var                                       2.635
# ========================================================================================
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2262: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# Intercept                                          0.453248
# Treatment[T.transfected]                           0.938117
# Trial_Type[T.outbound]                             0.000027
# Treatment[T.transfected]:Trial_Type[T.outbound]    0.000139
# Group Var                                               NaN
# dtype: float64

# %% [markdown]
# # Velocity Distributions in choice point

# %%
animal_list = animal_style.index
animal_list = [a for a in animal_list if a not in ["Odins", "control", "transfected"]]
animal_list = ["control", "transfected"]
results = {}
for i, animal in enumerate(animal_list):
    dataset_key = {"animal": animal, "track_type": "early_wtrack"}
    dataset = filter_opto_data(dataset_key)

    if not dataset:
        continue
    speeds = []
    for key in dataset.fetch("KEY"):
        epoch_key = {
            "nwb_file_name": key["nwb_file_name"],
            "position_interval_name": key["interval_list_name"],
        }
        epoch = ((PositionIntervalMap() & epoch_key) * TaskEpoch()).fetch1("epoch")

        query = PositionOutput().DLCPosV1() & key & {"epoch": epoch}
        if not query:
            continue
        intervals = (LocationTimes() & query).fetch1("intervals")

        pos_df = (DLCPosV1() & query).fetch1_dataframe()

        ind = interval_list_contains_ind(intervals, pos_df.index.values)
        print(ind.size / pos_df.index.size)

        speeds_i = pos_df.iloc[ind].speed.values
        speeds_i = speeds_i[~np.isnan(speeds_i)]
        speeds.extend(speeds_i)

        # break
    results[animal] = speeds
    # break
# Out:
# datasets: 42
# 0.025464949928469243
# 0.06427519743006291
# 0.08355972668148515
# 0.1466157322716023
# 0.017266372451116195
# 0.047425179476023246
# 0.05833746488183771
# 0.056642693872999944
# 0.09828270202706374
# 0.06664270110333767
# 0.06263356896268289
# 0.055216068835119064
# 0.10226212046340526
# 0.1108889193261197
# 0.0898246356494829
# 0.08537630247920179
# 0.10140338637400381
# 0.0475142444917223
# 0.051786316581480425
# 0.05440479161467432
# 0.05968498129905705
# 0.07240426961259984
# 0.06357811729916214
# 0.05009855453350854
# 0.04978772674642995
# 0.05109647929477064
# 0.1127856906260351
# 0.04788708961845608
# 0.05384359585434795
# 0.050064693300942674
# 0.05886243386243386
# 0.029985007496251874
# 0.035954310368669966
# 0.0539711490631736
# 0.05775673505551402
# 0.0495582848524025
# 0.05354929344682258
# 0.0462059019303306
# 0.040918384262584956
# 0.0486965617859994
# 0.04120871553315153
# datasets: 44
# 0.08118343195266273
# 0.0963931718061674
# 0.12263967835851934
# 0.10195472967384411
# 0.09375344276743418
# 0.08863145815688096
# 0.09768936665373747
# 0.10334173510041467
# 0.0881510057867181
# 0.07103141506811232
# 0.09315326285492888
# 0.07940432861945378
# 0.07671746259197001
# 0.08904314686266504
# 0.11026943033935459
# 0.10742106284478696
# 0.04848691792223313
# 0.05401646843549863
# 0.07251500754981033
# 0.06589289649599647
# 0.05116496476341148
# 0.06908716159974633
# 0.04396497580079063
# 0.0555699529821184
# 0.06839970501474926
# 0.0655464980868408
# 0.08424657534246575
# 0.0946164199192463
# 0.07878771089010167
# 0.0872163807415606
# 0.09109473742307586
# 0.09910735956419729
# 0.08311989431398452
# 0.08784347498452512
# 0.08125326083971772
# 0.10282042127811496
# 0.06089141647930168
# 0.09990054149629793
# 0.09403574684383546
# 0.12443724607444823
# 0.04795273426765595
# 0.03727767400308617
# 0.030016871309401068
# 0.053283548199914224

# %%
for i, (animal, speeds) in enumerate(results.items()):
    val = speeds
    # val = np.log10(val)
    violin_scatter(val, pos=i, color=animal_style.loc[animal, "color"], mark_mean=True)
# plt.yscale("log")
plt.xticks(range(len(results)), results.keys(), rotation=-90)
# Out:
# ([<matplotlib.axis.XTick at 0x7f818fd77af0>,
#   <matplotlib.axis.XTick at 0x7f818fd773d0>],
#  [Text(0, 0, 'control'), Text(1, 0, 'transfected')])

# %%
from spyglass.position.v1 import DLCPosV1
from spyglass.common import interval_list_contains_ind

pos_df = (DLCPosV1() & query).fetch1_dataframe()

ind = interval_list_contains_ind(intervals, pos_df.index.values)

speeds = pos_df.iloc[ind].speed.values
speeds = speeds[~np.isnan(speeds)]
print(speeds.shape)
violin_scatter(speeds)
# Out:
# (3664,)
