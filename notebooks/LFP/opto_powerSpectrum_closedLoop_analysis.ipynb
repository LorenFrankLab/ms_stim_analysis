# %%
# %reload_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt

from ms_stim_analysis.Analysis.lfp_analysis import opto_spectrum_analysis
from ms_stim_analysis.Analysis.utils import bootstrap
from ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol import OptoStimProtocol, OptoStimProtocolLaser, OptoStimProtocolClosedLoop
from ms_stim_analysis.Style.style_guide import animal_style
# Out:
# [2025-08-28 11:06:38,330][INFO]: DataJoint 0.14.6 connected to sambray@lmf-db.cin.ucsf.edu:3306

# %%
# Logging for database export. Not necessary for replication

from spyglass.common.common_usage import Export, ExportSelection

paper_key = {"paper_id": "ms_stim_analysis"}

analysis_id = "opto_power_spectrum_closedLoop"
ExportSelection().start_export(**paper_key, analysis_id=analysis_id)
# Out:
# [11:06:45][INFO] Spyglass: Resuming {'export_id': 40}

# %% [markdown]
# ### Power Spectrum and statistics for individual animals, closed-loop

# %%
qq = [np.array(_x) for _x in score_list]

# %%
animal_list = [
    "Winnie",
    "Frodo",
    "Totoro",
    "Banner",
    "Odins",
    "Bilbo",
    "Wallie",
    "Olive",
    "Yoshi",
    # "control",
    # "transfected",
]

phase_list = np.array([90, 180, 270, 360])
track_type = "lineartrack"
# track_type = "early_wtrack"
dlc_pos = "wtrack" in track_type

# phase_list = np.array(
#     [
#         90,
#     ]
# )
# track_type = "early_wtrack"

# phase_list = np.array([90,])
bootstrap_scores = True
suppression_scores = {}

score_fig, score_ax = plt.subplots(nrows=2, sharex=True, sharey=True, figsize=(12, 6))
for n_animal, animal in enumerate(animal_list):
    score_list = []
    for phase in phase_list:
        dataset_key = {
            "optogenetic_protocol": "phase_targeting",
            "laser_power": 77,
            "animal": animal,
            "min_pulse_length": 25,
            "max_pulse_length": 42,
            "targeted_phase": phase,
            "track_type": track_type,
        }

        fig, scores = opto_spectrum_analysis(
            dataset_key, return_distributions=True, dlc_pos=dlc_pos
        )
        score_list.append(list(scores))
        plt.rcParams["svg.fonttype"] = "none"
        dir = f"../Figures/Fig_1/Fig_1/"
        if fig is not None:
            fig.savefig(
                f"{dir}/Fig_1h_opto_spectrum_{track_type}_phase{phase}_{animal}.svg"
            )
            # fig.savefig(
            #     f"./Figures_20241201/lfp_spectrum_{track_type}_phase{phase}_{animal}.svg"
            # )

    # score_list = np.array(score_list)
    score_list = [np.array(_x) for _x in score_list]
    suppression_scores[animal] = [_x[0] for _x in score_list]
    score_names = ["suppression", "entrainment"]
    width = 20
    color = animal_style.loc[animal, "color"]  # plt.cm.jet(n_animal/8)
    for i in range(2):
        if bootstrap_scores:
            data = [bootstrap(dat[i], int(1e4)) for dat in score_list]
        else:
            data = [dat[i] for dat in score_list]
        violin = score_ax[i].violinplot(
            data,
            showmeans=False,
            showextrema=False,
            showmedians=False,
            positions=phase_list + n_animal * width / 2,
            widths=width,
        )
        for pc in violin["bodies"]:
            pc.set_facecolor(color)
            pc.set_alpha(0.3)
        score_ax[i].scatter(
            phase_list + n_animal * width / 2,
            [np.mean(d) for d in data],
            label=dataset_key["animal"],
            color=color,
        )
        score_ax[i].set_ylabel(score_names[i])
        score_ax[i].set_xticks(phase_list)
    score_ax[0].legend()

score_fig.savefig(f"{dir}/Fig_1i_lfp_spectrum_scores_closed_loop.svg")
# Out:
# [11:37:12][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Winnie20220717_.nwb', 'interval_list_name': 'pos 11 valid times'}
# [11:37:41][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:37:59][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:37:59][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:37:59][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:38:02][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:38:02][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [00:39, 39.78s/it]
# {'nwb_file_name': 'Winnie20220717_.nwb', 'interval_list_name': 'pos 3 valid times'}
# [11:38:21][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:38:38][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:38:38][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:38:38][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:38:41][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:38:41][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [01:18, 39.05s/it]
# [11:38:43][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Winnie20220717_.nwb', 'interval_list_name': 'pos 13 valid times'}
# [11:39:11][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:39:31][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:39:31][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:39:31][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:39:34][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:39:34][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [00:41, 41.29s/it]
# {'nwb_file_name': 'Winnie20220717_.nwb', 'interval_list_name': 'pos 5 valid times'}
# [11:39:52][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:40:11][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:40:11][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:40:11][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:40:14][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:40:14][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [01:21, 40.62s/it]
# [11:40:16][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Winnie20220717_.nwb', 'interval_list_name': 'pos 15 valid times'}
# [11:40:45][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:41:03][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:41:03][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:41:04][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:41:06][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:41:06][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [00:39, 39.65s/it]
# {'nwb_file_name': 'Winnie20220717_.nwb', 'interval_list_name': 'pos 7 valid times'}
# [11:41:24][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:41:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:41:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:41:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:41:47][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:41:47][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [01:20, 40.05s/it]
# [11:41:48][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Winnie20220717_.nwb', 'interval_list_name': 'pos 17 valid times'}
# [11:42:17][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:42:35][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:42:35][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:42:35][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:42:37][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:42:37][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [00:38, 38.54s/it]
# {'nwb_file_name': 'Winnie20220717_.nwb', 'interval_list_name': 'pos 9 valid times'}
# [11:42:55][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:43:13][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:43:13][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:43:13][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:43:16][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:43:16][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [01:16, 38.47s/it]
# [11:43:24][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 1
# datasets: 1
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Frodo20230811_.nwb', 'interval_list_name': 'pos 3 valid times'}
# [11:44:19][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 123.30416347586447]
# [11:44:37][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 123.30416347586447]
# [11:44:37][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:44:37][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:44:53][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:44:53][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:18, 78.00s/it]
# [11:44:54][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 1
# datasets: 1
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Frodo20230811_.nwb', 'interval_list_name': 'pos 7 valid times'}
# [11:45:47][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 123.30416347586447]
# [11:46:04][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 123.30416347586447]
# [11:46:05][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:46:05][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:46:19][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:46:20][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:14, 74.93s/it]
# [11:46:21][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 1
# datasets: 1
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Frodo20230811_.nwb', 'interval_list_name': 'pos 11 valid times'}
# [11:47:13][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 123.30416347586447]
# [11:47:31][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 123.30416347586447]
# [11:47:31][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:47:31][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:47:46][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:47:46][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:15, 75.26s/it]
# [11:47:47][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 1
# datasets: 1
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Frodo20230811_.nwb', 'interval_list_name': 'pos 15 valid times'}
# [11:48:40][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 123.30416347586447]
# [11:48:58][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 123.30416347586447]
# [11:48:58][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:48:58][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:49:13][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:49:13][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:14, 74.95s/it]
# [11:49:15][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Totoro20220607_.nwb', 'interval_list_name': 'pos 11 valid times'}
# [11:49:55][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:50:13][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:50:13][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:50:13][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:50:24][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:50:24][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:05, 65.60s/it]
# {'nwb_file_name': 'Totoro20220607_.nwb', 'interval_list_name': 'pos 3 valid times'}
# [11:51:01][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:51:18][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:51:19][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:51:19][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:51:29][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:51:29][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:16, 68.26s/it]
# [11:51:43][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Totoro20220607_.nwb', 'interval_list_name': 'pos 13 valid times'}
# [11:52:23][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:52:39][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:52:40][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:52:40][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:52:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:52:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:00, 60.25s/it]
# {'nwb_file_name': 'Totoro20220607_.nwb', 'interval_list_name': 'pos 5 valid times'}
# [11:53:23][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:53:39][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:53:40][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:53:40][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:53:50][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:53:50][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:06, 63.38s/it]
# [11:54:02][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Totoro20220607_.nwb', 'interval_list_name': 'pos 15 valid times'}
# [11:54:41][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:54:57][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:54:57][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:54:57][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:55:07][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:55:08][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:35, 95.24s/it]
# {'nwb_file_name': 'Totoro20220607_.nwb', 'interval_list_name': 'pos 7 valid times'}
# [11:56:16][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:56:33][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:56:33][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:56:33][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:56:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:56:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:38, 79.43s/it]
# [11:56:52][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Totoro20220607_.nwb', 'interval_list_name': 'pos 17 valid times'}
# [11:57:31][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:57:48][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:57:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:57:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:57:59][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:58:00][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:43, 103.77s/it]
# {'nwb_file_name': 'Totoro20220607_.nwb', 'interval_list_name': 'pos 9 valid times'}
# [11:59:15][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:59:32][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [11:59:32][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:59:32][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:59:42][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [11:59:42][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:46, 83.32s/it]
# [11:59:55][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Banner20220215_.nwb', 'interval_list_name': 'pos 0 valid times'}
# [12:00:32][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:00:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:00:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:00:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:00:57][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:00:57][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [00:52, 52.13s/it]
# {'nwb_file_name': 'Banner20220216_.nwb', 'interval_list_name': 'pos 0 valid times'}
# [12:01:36][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:02:01][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:02:01][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:02:01][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:02:10][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:02:10][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:05, 62.53s/it]
# [12:02:12][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Banner20220215_.nwb', 'interval_list_name': 'pos 1 valid times'}
# [12:02:55][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:03:14][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:03:14][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:03:14][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:03:21][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:03:21][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [00:55, 55.15s/it]
# {'nwb_file_name': 'Banner20220216_.nwb', 'interval_list_name': 'pos 1 valid times'}
# [12:03:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:04:07][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:04:07][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:04:07][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:04:15][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:04:15][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [01:49, 54.54s/it]
# [12:04:17][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Banner20220215_.nwb', 'interval_list_name': 'pos 2 valid times'}
# [12:05:10][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:05:36][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:05:36][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:05:36][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:05:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:05:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:06, 66.63s/it]
# {'nwb_file_name': 'Banner20220216_.nwb', 'interval_list_name': 'pos 2 valid times'}
# [12:06:18][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:06:38][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:06:38][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:06:38][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:06:45][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:06:45][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:07, 63.77s/it]
# [12:06:46][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Banner20220215_.nwb', 'interval_list_name': 'pos 3 valid times'}
# [12:07:29][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:07:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:07:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:07:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:07:56][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:07:56][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [00:59, 59.09s/it]
# {'nwb_file_name': 'Banner20220216_.nwb', 'interval_list_name': 'pos 3 valid times'}
# [12:08:29][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:08:54][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:08:54][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:08:54][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:09:02][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:09:02][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:04, 62.11s/it]
# [12:09:14][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 3
# datasets: 3
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Odins20220126_.nwb', 'interval_list_name': 'pos 3 valid times'}
# [12:10:00][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:10:22][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:10:22][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:10:22][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:10:30][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:10:30][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [00:59, 59.29s/it]
# {'nwb_file_name': 'Odins20220126_.nwb', 'interval_list_name': 'pos 8 valid times'}
# [12:11:01][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:11:25][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:11:26][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:11:26][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:11:32][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:11:32][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:00, 60.40s/it]
# {'nwb_file_name': 'Odins20220216_.nwb', 'interval_list_name': 'pos 0 valid times'}
# [12:12:03][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:12:25][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:12:25][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:12:25][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:12:33][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:12:33][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 3it [03:02, 60.77s/it]
# [12:12:35][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 1
# datasets: 1
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Odins20220216_.nwb', 'interval_list_name': 'pos 2 valid times'}
# [12:13:31][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:13:57][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:13:57][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:13:57][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:14:04][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:14:04][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:14, 74.37s/it]
# [12:14:06][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 1
# datasets: 1
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Odins20220216_.nwb', 'interval_list_name': 'pos 4 valid times'}
# [12:15:05][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:15:28][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:15:29][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:15:29][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:15:36][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:15:36][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:11, 71.78s/it]
# [12:15:38][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 1
# datasets: 1
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Odins20220216_.nwb', 'interval_list_name': 'pos 6 valid times'}
# [12:16:26][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:16:46][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:16:46][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:16:46][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:16:53][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:16:53][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [00:58, 58.63s/it]
# [12:16:59][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 0
# datasets: 0
# 0it [00:00, ?it/s]
# [12:17:23][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 0
# datasets: 0
# 0it [00:00, ?it/s]
# [12:17:43][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 0
# datasets: 0
# 0it [00:00, ?it/s]
# [12:17:59][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 0
# datasets: 0
# 0it [00:00, ?it/s]
# [12:18:17][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Wallie20220914_.nwb', 'interval_list_name': 'pos 11 valid times'}
# [12:19:10][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:19:30][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:19:30][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:19:30][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:19:41][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:19:41][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:09, 69.21s/it]
# {'nwb_file_name': 'Wallie20220914_.nwb', 'interval_list_name': 'pos 3 valid times'}
# [12:20:18][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:20:38][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:20:38][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:20:38][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:20:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:20:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:17, 68.65s/it]
# [12:20:51][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Wallie20220914_.nwb', 'interval_list_name': 'pos 13 valid times'}
# [12:21:40][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:21:58][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:21:58][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:21:58][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:22:10][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:22:10][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:05, 65.88s/it]
# {'nwb_file_name': 'Wallie20220914_.nwb', 'interval_list_name': 'pos 5 valid times'}
# [12:22:48][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:23:06][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:23:06][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:23:06][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:23:17][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:23:17][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:12, 66.25s/it]
# [12:23:19][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Wallie20220914_.nwb', 'interval_list_name': 'pos 15 valid times'}
# [12:24:05][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:24:26][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:24:26][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:24:26][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:24:37][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:24:37][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:06, 66.27s/it]
# {'nwb_file_name': 'Wallie20220914_.nwb', 'interval_list_name': 'pos 7 valid times'}
# [12:25:15][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:25:37][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:25:37][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:25:37][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:25:50][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:25:50][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:19, 69.63s/it]
# [12:25:52][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 1
# datasets: 1
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Wallie20220914_.nwb', 'interval_list_name': 'pos 17 valid times'}
# [12:26:42][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:27:01][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:27:02][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:27:02][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:27:13][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:27:13][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:08, 68.04s/it]
# [12:27:20][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Olive20220707_.nwb', 'interval_list_name': 'pos 11 valid times'}
# [12:28:07][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:28:25][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:28:26][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:28:26][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:28:36][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:28:36][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:03, 63.18s/it]
# {'nwb_file_name': 'Olive20220707_.nwb', 'interval_list_name': 'pos 3 valid times'}
# [12:29:12][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:29:32][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:29:32][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:29:33][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:29:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:29:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:10, 65.15s/it]
# [12:29:45][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Olive20220707_.nwb', 'interval_list_name': 'pos 13 valid times'}
# [12:30:33][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:30:52][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:30:53][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:30:53][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:31:03][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:31:03][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:06, 66.96s/it]
# {'nwb_file_name': 'Olive20220707_.nwb', 'interval_list_name': 'pos 5 valid times'}
# [12:31:38][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:31:59][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:31:59][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:31:59][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:32:09][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:32:09][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:13, 66.92s/it]
# [12:32:11][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Olive20220707_.nwb', 'interval_list_name': 'pos 15 valid times'}
# [12:32:59][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:33:19][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:33:20][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:33:20][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:33:30][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:33:30][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:07, 67.17s/it]
# {'nwb_file_name': 'Olive20220707_.nwb', 'interval_list_name': 'pos 7 valid times'}
# [12:34:06][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:34:27][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:34:28][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:34:28][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:34:38][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:34:38][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:15, 68.00s/it]
# [12:34:40][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Olive20220707_.nwb', 'interval_list_name': 'pos 17 valid times'}
# [12:35:36][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:35:57][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:35:57][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:35:57][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:36:07][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:36:07][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:11, 71.31s/it]
# {'nwb_file_name': 'Olive20220707_.nwb', 'interval_list_name': 'pos 9 valid times'}
# [12:36:44][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:37:09][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:37:10][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:37:10][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:37:21][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:37:21][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:24, 72.34s/it]
# [12:37:30][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Yoshi20220513_.nwb', 'interval_list_name': 'pos 11 valid times'}
# [12:38:17][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:38:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:38:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:38:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:38:55][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:38:55][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:11, 71.81s/it]
# {'nwb_file_name': 'Yoshi20220513_.nwb', 'interval_list_name': 'pos 3 valid times'}
# [12:39:42][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:40:03][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:40:03][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:40:03][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:40:15][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:40:15][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:31, 75.77s/it]
# [12:40:17][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Yoshi20220513_.nwb', 'interval_list_name': 'pos 13 valid times'}
# [12:41:04][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:41:24][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:41:24][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:41:24][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:41:35][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:41:35][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:05, 65.66s/it]
# {'nwb_file_name': 'Yoshi20220513_.nwb', 'interval_list_name': 'pos 5 valid times'}
# [12:42:10][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:42:30][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:42:30][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:42:30][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:42:41][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:42:41][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:11, 65.89s/it]
# [12:42:43][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Yoshi20220513_.nwb', 'interval_list_name': 'pos 15 valid times'}
# [12:43:28][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:43:48][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:43:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:43:49][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:43:58][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:43:58][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:04, 64.27s/it]
# {'nwb_file_name': 'Yoshi20220513_.nwb', 'interval_list_name': 'pos 7 valid times'}
# [12:44:37][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:45:02][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:45:02][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:45:02][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:45:14][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:45:14][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:19, 69.55s/it]
# [12:45:16][WARNING] Spyglass: Cannot export log join for
# <class 'ms_stim_analysis.AnalysisTables.ms_opto_stim_protocol.OptoStimProtocolLaser'>
# datasets: 2
# datasets: 2
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Yoshi20220513_.nwb', 'interval_list_name': 'pos 17 valid times'}
# [12:46:04][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:46:24][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:46:24][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:46:24][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:46:36][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:46:36][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 1it [01:09, 69.18s/it]
# {'nwb_file_name': 'Yoshi20220513_.nwb', 'interval_list_name': 'pos 9 valid times'}
# [12:47:12][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:47:32][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# linear_limits [10, 126.8923664781934]
# [12:47:32][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:47:32][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:47:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# [12:47:43][WARNING] Spyglass: DEPRECATION scheduled for Spyglass 0.6.0: interval_list_intersect
# 	Use Interval.intersect instead
# 2it [02:16, 68.25s/it]

# %%
suppression_scores.pop("Bilbo")
# Out:
# [array([nan, nan]), array([nan, nan]), array([nan, nan]), array([nan, nan])]

# %%
from ms_stim_analysis.Analysis.utils import violin_scatter

boxplot = False

phase_ind = np.where(phase_list == 90)[0][0]
plot_order = [
    "Wallie",
    "Olive",
    "Yoshi",
    "Winnie",
    "Frodo",
    "Totoro",
    "Banner",
    "Odins",
]

fig = plt.figure(figsize=(12, 6))
ax = fig.gca()
for i, animal in enumerate(plot_order):
    if not boxplot:
        # print(
        #     animal,
        #     np.mean(suppression_scores[animal]),
        #     np.std(suppression_scores[animal]),
        # )
        violin_scatter(
            np.squeeze(suppression_scores[animal][phase_ind]),
            pos=i,
            color=animal_style.loc[animal, "color"],
            mark_mean=True,
            alpha=0.1,
        )
        plt.scatter(
            [i],
            np.mean(suppression_scores[animal][phase_ind]),
            facecolor=animal_style.loc[animal, "color"],
            edgecolor="k",
            zorder=10,
        )
    else:
        c = animal_style.loc[animal, "color"]
        plt.boxplot(
            np.squeeze(suppression_scores[animal][phase_ind]),
            positions=[i],
            widths=0.4,
            patch_artist=True,
            showmeans=False,
            # showmedians=False,
            boxprops=dict(facecolor=c, alpha=0.5, edgecolor=c, lw=1.5),
            capprops=dict(color=c),
            whiskerprops=dict(color=c, lw=2),
            flierprops=dict(color=c, markeredgecolor=c),
            medianprops=dict(color=c),
            notch=True,
            showfliers=False,
        )

    plt.fill_between(
        [i - 0.5, i + 0.5],
        -2,
        2,
        facecolor=animal_style.loc[animal, "background"],
        alpha=0.2,
        zorder=-1,
    )
ax.set_xticks(range(len(plot_order)), labels=plot_order)
ax.set_ylim(-1.05, 1.05)
ax.set_xlim(-0.5, len(plot_order) - 0.5)
ax.set_ylabel("Suppression")
plt.rcParams["svg.fonttype"] = "none"
boxplot_tag = "boxplot" if boxplot else "violin"
fig.savefig(
    f"../Figures/Fig_1/Fig_1i_theta_90_lineartrack_suppression_{boxplot_tag}.svg"
)

# %%
import statsmodels.api as sms
import pandas as pd

model_df = []
for i, animal in enumerate(suppression_scores.keys()):
    data = suppression_scores[animal][0]  # [:,1][0]
    for d in data:
        model_df.append(
            {
                "Animal": i,
                "Treatment": (
                    "transfected"
                    if animal_style.loc[animal, "background"] == "indianred"
                    else "control"
                ),
                "Score": d,
            }
        )


model_df = pd.DataFrame(model_df)

from statsmodels.formula.api import mixedlm

# Convert the 'Treatment' column to a categorical variable
model_df["Treatment"] = model_df["Treatment"].astype("category")
# model_df['Animal'] = model_df['Treatment'].astype('category')

# Fit the mixed-effects model
model = mixedlm("Score ~ Treatment", model_df, groups=model_df["Animal"])
result = model.fit()

# Print the summary of the model
print(result.summary())
result.pvalues
# Out:
#               Mixed Linear Model Regression Results
# ==================================================================
# Model:                MixedLM    Dependent Variable:    Score
# No. Observations:     48518      Method:                REML
# No. Groups:           8          Scale:                 0.0661
# Min. group size:      1122       Log-Likelihood:        -2958.5477
# Max. group size:      11424      Converged:             Yes
# Mean group size:      6064.8
# ------------------------------------------------------------------
#                          Coef. Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------
# Intercept                0.117    0.031  3.776 0.000  0.056  0.177
# Treatment[T.transfected] 0.423    0.039 10.827 0.000  0.346  0.499
# Group Var                0.003    0.006
# ==================================================================
# /home/sambray/mambaforge-pypy3/envs/spyglass/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Intercept                   1.592606e-04
# Treatment[T.transfected]    2.564890e-27
# Group Var                   8.756228e-02
# dtype: float64

# %%
model_df = []
score_index = 0
n_transfected = 0
n_control = 0
for i, animal in enumerate(suppression_scores.keys()):
    data = suppression_scores[animal][0]
    print(animal, data.shape)
    for d in data:
        model_df.append(
            {
                "Animal": animal,
                "Treatment": (
                    "transfected"
                    if animal_style.loc[animal, "background"] == "indianred"
                    else "control"
                ),
                "Score": d,
            }
        )
    if animal_style.loc[animal, "background"] == "indianred":
        n_transfected += len(data)
    else:
        n_control += len(data)
print(n_transfected, n_control)
# Out:
# Winnie (6720,)
# Frodo (1122,)
# Totoro (7128,)
# Banner (7874,)
# Odins (11424,)
# Wallie (6264,)
# Olive (4242,)
# Yoshi (3744,)
# 34268 14250

# %% [markdown]
# ### Power Spectrum and statistics for pooled animals, closed-loop

# %%
phase_list = np.array([90, 180, 270, 360])
bootstrap_scores = True


score_fig, score_ax = plt.subplots(nrows=2, sharex=True, sharey=True, figsize=(12, 6))
for n_genetic, transfected in enumerate([True, False]):
    score_list = []
    for phase in phase_list:
        dataset_key = {
            "optogenetic_protocol": "phase_targeting",
            "laser_power": 77,
            "animal": "",
            "min_pulse_length": 25,
            "targeted_phase": phase,
            "track_type": "wtrack",
            "max_pulse_length": 42,
            "transfected": transfected,
        }

        fig, scores = opto_spectrum_analysis(dataset_key, return_distributions=True)
        score_list.append(list(scores))

    score_list = np.array(score_list)
    score_names = ["suppression", "entrainment"]
    width = 20
    for i in range(2):
        if bootstrap_scores:
            data = [bootstrap(dat, int(1e4)) for dat in score_list[:, i]]
        else:
            data = score_list[:, i].copy()
        score_ax[i].violinplot(
            data,
            showmeans=False,
            showextrema=False,
            showmedians=False,
            positions=phase_list + n_genetic * width / 2,
            widths=width,
        )
        score_ax[i].scatter(
            phase_list + n_genetic * width / 2,
            [np.mean(d) for d in data],
            label=transfected,
        )
        score_ax[i].set_ylabel(score_names[i])
        score_ax[i].set_xticks(phase_list)
    score_ax[0].legend()


# animal_list = ['Totoro','Banner','Winnie','Wallie','Yoshi', 'Olive'] # ['Winnie',]#
# phase_list = np.array([90,180,270,360])
# bootstrap_scores = True


# score_fig, score_ax = plt.subplots(nrows=2,sharex=True,sharey=True,figsize=(12,6))
# for n_animal,animal in enumerate(animal_list):
#     score_list = []
#     for phase in phase_list:
#         dataset_key = {'optogenetic_protocol':'phase_targeting',
#                             "laser_power": 77,
#                             "animal":animal,
#                             "min_pulse_length":25,
#                             "max_pulse_length":42,
#                             'targeted_phase':phase,
#                             "track_type":'lineartrack'}

#         fig, scores = opto_spectrum_analysis(dataset_key,return_distributions=True)
#         score_list.append(list(scores))

#     score_list = np.array(score_list)
#     score_names = ["suppression","entrainment"]
#     width = 20
#     for i in range(2):
#         if bootstrap_scores:
#             data = [bootstrap(dat,int(1e4)) for dat in score_list[:,i]]
#         else:
#             data = score_list[:,i].copy()
#         score_ax[i].violinplot(data,
#                         showmeans=False,
#                         showextrema=False,
#                         showmedians=False,
#                         positions=phase_list+n_animal*width/2,
#                         widths=width,)
#         score_ax[i].scatter(phase_list+n_animal*width/2,[np.mean(d) for d in data],label=dataset_key["animal"])
#         score_ax[i].set_ylabel(score_names[i])
#         score_ax[i].set_xticks(phase_list)
#     score_ax[0].legend()
# Out:
# datasets: 45
# datasets: 45
# 0it [00:00, ?it/s]
# {'nwb_file_name': 'Banner20220224_.nwb', 'interval_list_name': 'pos 0 valid times'}
# wtrack_limit 30.300000000000097
# 1it [00:07,  7.11s/it]
# {'nwb_file_name': 'Banner20220224_.nwb', 'interval_list_name': 'pos 1 valid times'}
# wtrack_limit 28.59999999999952
# 2it [00:11,  5.55s/it]
# {'nwb_file_name': 'Banner20220224_.nwb', 'interval_list_name': 'pos 2 valid times'}
# wtrack_limit 31.199999999999854
# 3it [00:16,  5.45s/it]
# {'nwb_file_name': 'Banner20220224_.nwb', 'interval_list_name': 'pos 3 valid times'}
# wtrack_limit 29.37999999999982
# 4it [00:22,  5.38s/it]
# {'nwb_file_name': 'Banner20220224_.nwb', 'interval_list_name': 'pos 4 valid times'}
# wtrack_limit 32.95
# 5it [00:27,  5.47s/it]
# {'nwb_file_name': 'Banner20220224_.nwb', 'interval_list_name': 'pos 5 valid times'}
# wtrack_limit 30.99999999999994
# 6it [00:31,  5.00s/it]
# {'nwb_file_name': 'Banner20220224_.nwb', 'interval_list_name': 'pos 6 valid times'}
# wtrack_limit 34.30000000000001
# 7it [00:36,  4.89s/it]
# {'nwb_file_name': 'Banner20220224_.nwb', 'interval_list_name': 'pos 7 valid times'}
# wtrack_limit 28.630000000000067
# 8it [00:41,  4.87s/it]
# {'nwb_file_name': 'Banner20220225_.nwb', 'interval_list_name': 'pos 0 valid times'}
# wtrack_limit 32.24999999999994
# 9it [00:46,  4.84s/it]
# {'nwb_file_name': 'Banner20220225_.nwb', 'interval_list_name': 'pos 1 valid times'}
# wtrack_limit 30.759999999999938
# 10it [00:50,  4.84s/it]
# {'nwb_file_name': 'Banner20220225_.nwb', 'interval_list_name': 'pos 2 valid times'}
# wtrack_limit 33.949999999999946
# 11it [00:55,  4.76s/it]
# {'nwb_file_name': 'Banner20220225_.nwb', 'interval_list_name': 'pos 3 valid times'}
# wtrack_limit 29.70999999999985
# 12it [00:59,  4.54s/it]
# {'nwb_file_name': 'Banner20220225_.nwb', 'interval_list_name': 'pos 4 valid times'}
# wtrack_limit 31.749999999999954
# 13it [01:03,  4.49s/it]
# {'nwb_file_name': 'Banner20220225_.nwb', 'interval_list_name': 'pos 5 valid times'}
# wtrack_limit 31.95999999999986
# 14it [01:08,  4.46s/it]
# {'nwb_file_name': 'Banner20220225_.nwb', 'interval_list_name': 'pos 6 valid times'}
# wtrack_limit 32.0499999999999
# 15it [01:13,  4.58s/it]
# {'nwb_file_name': 'Banner20220225_.nwb', 'interval_list_name': 'pos 7 valid times'}
# wtrack_limit 30.639999999999965
# 16it [01:18,  4.71s/it]
# {'nwb_file_name': 'Totoro20220613_.nwb', 'interval_list_name': 'pos 1 valid times'}
# wtrack_limit 28.32999999999928
# 17it [01:24,  5.13s/it]
# {'nwb_file_name': 'Totoro20220613_.nwb', 'interval_list_name': 'pos 3 valid times'}
# wtrack_limit 26.77000000000004
# 18it [01:31,  5.64s/it]
# {'nwb_file_name': 'Totoro20220614_.nwb', 'interval_list_name': 'pos 1 valid times'}
# wtrack_limit 28.330000000000048
# 19it [01:38,  6.29s/it]
# {'nwb_file_name': 'Totoro20220614_.nwb', 'interval_list_name': 'pos 11 valid times'}
# wtrack_limit 28.54000000000019
# 20it [01:48,  7.35s/it]
# {'nwb_file_name': 'Totoro20220614_.nwb', 'interval_list_name': 'pos 13 valid times'}
# wtrack_limit 30.249999999999773
# 21it [02:36, 19.48s/it]
# {'nwb_file_name': 'Totoro20220614_.nwb', 'interval_list_name': 'pos 15 valid times'}
# wtrack_limit 29.649999999999714
# 22it [03:16, 25.72s/it]
# {'nwb_file_name': 'Totoro20220614_.nwb', 'interval_list_name': 'pos 3 valid times'}
# wtrack_limit 30.670000000000023
# 23it [03:23, 20.05s/it]
# {'nwb_file_name': 'Totoro20220614_.nwb', 'interval_list_name': 'pos 5 valid times'}
# wtrack_limit 27.940000000000055
# 24it [03:30, 16.05s/it]
# {'nwb_file_name': 'Totoro20220614_.nwb', 'interval_list_name': 'pos 7 valid times'}
# wtrack_limit 30.519999999999946
# 25it [03:37, 13.46s/it]
# {'nwb_file_name': 'Totoro20220614_.nwb', 'interval_list_name': 'pos 9 valid times'}
# wtrack_limit 30.339999999999918
# 26it [03:45, 11.87s/it]
# {'nwb_file_name': 'Winnie20220719_.nwb', 'interval_list_name': 'pos 1 valid times'}
# wtrack_limit 27.250000000000046
# 27it [04:03, 13.56s/it]
# {'nwb_file_name': 'Winnie20220719_.nwb', 'interval_list_name': 'pos 11 valid times'}
# wtrack_limit 25.719999999999946
# 28it [04:08, 10.89s/it]
# {'nwb_file_name': 'Winnie20220719_.nwb', 'interval_list_name': 'pos 13 valid times'}
# wtrack_limit 28.78000000000001
# 29it [04:12,  8.99s/it]
# {'nwb_file_name': 'Winnie20220719_.nwb', 'interval_list_name': 'pos 15 valid times'}
# wtrack_limit 27.249999999999943
# 30it [04:17,  7.66s/it]
# {'nwb_file_name': 'Winnie20220719_.nwb', 'interval_list_name': 'pos 17 valid times'}
# wtrack_limit 28.270000000000078
# 31it [04:22,  6.95s/it]
# {'nwb_file_name': 'Winnie20220719_.nwb', 'interval_list_name': 'pos 3 valid times'}
# wtrack_limit 27.70000000000039
# 32it [04:27,  6.43s/it]
# {'nwb_file_name': 'Winnie20220719_.nwb', 'interval_list_name': 'pos 5 valid times'}
# wtrack_limit 27.160000000000053
# 33it [04:31,  5.75s/it]
# {'nwb_file_name': 'Winnie20220719_.nwb', 'interval_list_name': 'pos 7 valid times'}
# wtrack_limit 25.899999999999984
# 34it [04:39,  6.21s/it]
# {'nwb_file_name': 'Winnie20220719_.nwb', 'interval_list_name': 'pos 9 valid times'}
# wtrack_limit 27.009999999999437
# 35it [04:43,  5.68s/it]
# {'nwb_file_name': 'Winnie20220720_.nwb', 'interval_list_name': 'pos 1 valid times'}
# wtrack_limit 28.600000000000026
# 36it [04:47,  5.28s/it]
# {'nwb_file_name': 'Winnie20220720_.nwb', 'interval_list_name': 'pos 11 valid times'}
# wtrack_limit 30.729999999999844
# 37it [04:51,  4.67s/it]
# {'nwb_file_name': 'Winnie20220720_.nwb', 'interval_list_name': 'pos 13 valid times'}
# wtrack_limit 30.220000000000336
# 38it [04:55,  4.40s/it]
# {'nwb_file_name': 'Winnie20220720_.nwb', 'interval_list_name': 'pos 15 valid times'}
# wtrack_limit 30.580000000000155
# 39it [04:58,  4.07s/it]
# {'nwb_file_name': 'Winnie20220720_.nwb', 'interval_list_name': 'pos 3 valid times'}
# wtrack_limit 29.530000000000243
# 40it [05:02,  3.96s/it]
# {'nwb_file_name': 'Winnie20220720_.nwb', 'interval_list_name': 'pos 5 valid times'}
# wtrack_limit 28.959999999999887
# 41it [05:05,  3.87s/it]
# {'nwb_file_name': 'Winnie20220720_.nwb', 'interval_list_name': 'pos 7 valid times'}
# wtrack_limit 30.4
# 42it [05:11,  4.55s/it]
# {'nwb_file_name': 'Winnie20220720_.nwb', 'interval_list_name': 'pos 9 valid times'}
# wtrack_limit 30.250000000000295
# 43it [05:15,  4.34s/it]
# {'nwb_file_name': 'Winnie20220722_.nwb', 'interval_list_name': 'pos 1 valid times'}
# wtrack_limit 27.099999999999856
# 44it [05:19,  4.08s/it]
# {'nwb_file_name': 'Winnie20220722_.nwb', 'interval_list_name': 'pos 3 valid times'}
# wtrack_limit 27.670000000000048
# 45it [05:24,  7.21s/it]
# datasets: 0
# datasets: 0
# 0it [00:00, ?it/s]
# datasets: 0
# datasets: 0
# 0it [00:00, ?it/s]
# datasets: 0
# datasets: 0
# 0it [00:00, ?it/s]
